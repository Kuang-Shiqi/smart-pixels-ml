# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.optimizers import Adam
import keras
from keras.models import Sequential, Model
from keras.layers import *
from keras.utils import Sequence
from keras.layers import Conv2D, MaxPooling2D
from qkeras import *

from keras.utils import Sequence
from keras.callbacks import CSVLogger
from keras.callbacks import EarlyStopping

import os
import random

pi = 3.14159265359

maxval=1e9
minval=1e-9

#import OptimizedDataGenerator as DG
#from loss import *
#from loss_kl import *
#from loss_hybrid2 import *
# Out:
# 2025-07-07 02:52:18.732458: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-07-07 02:52:18.732531: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-07-07 02:52:18.733666: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-07 02:52:18.740814: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-07 02:52:19.778348: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
#from loss_functions.loss_nll import *
from loss_functions.Slim_SSE import *
#from models.models import *
from models.Slim1D_model1 import *
import utils
# Out:
# 2025-07-07 02:52:22.116166: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3234 MB memory:  -> device: 0, name: NVIDIA A100-PCIE-40GB MIG 1g.5gb, pci bus id: 0000:81:00.0, compute capability: 8.0

# %%
# try auto sf
#import OptimizedDataGenerator as DG
#import OptimizedDataGenerator as DG
import OptimizedDataGenerator_v2 as DG

# %%
batch_size = 5000
val_batch_size = 5000
train_file_size = 68
val_file_size = 12

# %% [markdown]
# Training

# %%
def count_files_in_directory(directory_path):
    try:
        return len([f for f in os.listdir(directory_path) if os.path.isfile(os.path.join(directory_path, f))])
    except FileNotFoundError:
        print(f"Directory not found: {directory_path}")
        return 0

# %%
data_directory_path = '/depot/cms/users/kuang14/Smart_Pixel/dataset_s_series/largerWindowPreliminary/dataset_3sr_16x16_50x12P5_parquets/contained/train'

# %%
tfrecords_dir_train = "/depot/cms/users/kuang14/Smart_Pixel/tf_records/baseline_16x16_3sr_train_run2"
tfrecords_dir_validation = "/depot/cms/users/kuang14/Smart_Pixel/tf_records/baseline_16x16_3sr_val_run2"

# %%
# Count files in both directories
data_files_count = count_files_in_directory(data_directory_path)


# Print results
print(f"Number of files in data directory: {data_files_count}")
# Out:
# Number of files in data directory: 80

# %% [markdown]
# Create a new tfrecord can avoid the problem of not converging.

# %%
#utils.safe_remove_directory(tfrecords_dir_train)
#utils.safe_remove_directory(tfrecords_dir_validation)

# %%
validation_generator = DG.OptimizedDataGenerator(
    # Base directory where your parquet files are located
    dataset_base_dir = data_directory_path,
    is_directory_recursive = False,
    batch_size = val_batch_size,
    file_count = val_file_size,
    to_standardize = True,
    include_y_local = False,
    # Labels you want to extract
    labels_list = ['x-midplane', 'y-midplane', 'cotBeta'],  
    # Input shape for the model (time slices, height, width)
    input_shape = (2, 16, 16),
    transpose = (0, 2, 3, 1),
    shuffle = False,
    files_from_end = False,
    
    # New parameters specific to this generator
    tfrecords_dir = tfrecords_dir_validation,
    use_time_stamps = [0, 19],  # Specific time stamps to use
    quantize = False,  # Whether to use quantization during loading
    max_workers = 2  # For parallel processing
)
# Out:
# Processing Files...: 100%|██████████| 12/12 [00:02<00:00,  4.93it/s]
# Directory /depot/cms/users/kuang14/Smart_Pixel/tf_records/baseline_16x16_3sr_val_run2 is removed...
# Saving batches as TFRecords: 100%|██████████| 13/13 [00:05<00:00,  2.49it/s]
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# Metadata saved successfully ast /depot/cms/users/kuang14/Smart_Pixel/tf_records/baseline_16x16_3sr_val_run2/metadata.json
# Loading metadata from /depot/cms/users/kuang14/Smart_Pixel/tf_records/baseline_16x16_3sr_val_run2/metadata.json

# %%
train_generator = DG.OptimizedDataGenerator(
    # Base directory where your parquet files are located
    dataset_base_dir = data_directory_path,
    is_directory_recursive = False,
    batch_size = batch_size,
    file_count = train_file_size,
    to_standardize = True,
    include_y_local = False,
    # Labels you want to extract
    labels_list = ['x-midplane', 'y-midplane', 'cotBeta'],  
    # Input shape for the model (time slices, height, width)
    input_shape = (2, 16,16),
    transpose = (0, 2, 3, 1),
    shuffle = False,
    files_from_end = True,  # Using files from the end of the list
    
    # New parameters specific to this generator
    tfrecords_dir = tfrecords_dir_train,
    use_time_stamps = [0, 19],  # Specific time stamps to use
    quantize = False,  # Whether to use quantization during loading
    max_workers = 2  # For parallel processing
)
# Out:
# Processing Files...: 100%|██████████| 68/68 [00:13<00:00,  5.18it/s]
# Directory /depot/cms/users/kuang14/Smart_Pixel/tf_records/baseline_16x16_3sr_train_run2 is removed...
# Saving batches as TFRecords: 100%|██████████| 71/71 [00:27<00:00,  2.59it/s]
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# Metadata saved successfully ast /depot/cms/users/kuang14/Smart_Pixel/tf_records/baseline_16x16_3sr_train_run2/metadata.json
# Loading metadata from /depot/cms/users/kuang14/Smart_Pixel/tf_records/baseline_16x16_3sr_train_run2/metadata.json

# %%
train_generator.labels_scale
# Out:
# array([99.05740769, 24.81243883,  1.88567753])

# %%
input_shape = (16, 16, 2)
model = CreateSlim1DModel_NonQuantized(input_shape)  # Use slim model
model.summary()
# Out:
# Model: "smrtpxl_slim_nonquant"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_pxls/ (InputLayer)    [(None, 16, 16, 2)]          0         []
#
#  avg_pooling_2d_proj_x (Ave  (None, 16, 1, 2)             0         ['input_pxls/[0][0]']
#  ragePooling2D)
#
#  avg_pooling_2d_proj_y (Ave  (None, 1, 16, 2)             0         ['input_pxls/[0][0]']
#  ragePooling2D)
#
#  reshape_proj_x (Reshape)    (None, 16, 2)                0         ['avg_pooling_2d_proj_x[0][0]'
#                                                                     ]
#
#  reshape_proj_y (Reshape)    (None, 16, 2)                0         ['avg_pooling_2d_proj_y[0][0]'
#                                                                     ]
#
#  conv1d_proj_x (Conv1D)      (None, 14, 5)                35        ['reshape_proj_x[0][0]']
#
#  conv1d_proj_y (Conv1D)      (None, 14, 5)                35        ['reshape_proj_y[0][0]']
#
#  concatenate (Concatenate)   (None, 28, 5)                0         ['conv1d_proj_x[0][0]',
#                                                                      'conv1d_proj_y[0][0]']
#
#  activation_tanh_1 (Activat  (None, 28, 5)                0         ['concatenate[0][0]']
#  ion)
#
#  flatten (Flatten)           (None, 140)                  0         ['activation_tanh_1[0][0]']
#
#  dense_1 (Dense)             (None, 16)                   2256      ['flatten[0][0]']
#
#  activation_tanh_2 (Activat  (None, 16)                   0         ['dense_1[0][0]']
#  ion)
#
#  dense_2 (Dense)             (None, 16)                   272       ['activation_tanh_2[0][0]']
#
#  activation_tanh_3 (Activat  (None, 16)                   0         ['dense_2[0][0]']
#  ion)
#
#  dense_3 (Dense)             (None, 3)                    51        ['activation_tanh_3[0][0]']
#
# ==================================================================================================
# Total params: 2649 (10.35 KB)
# Trainable params: 2649 (10.35 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
'''
decay_steps = 90*train_generator.__len__()
alpha = 0.01
initial_learning_rate = 1e-3
warmup_target = 1e-1
warmup_steps = 10*train_generator.__len__()
'''
decay_steps = 90*train_generator.__len__()
alpha = 0.01
initial_learning_rate = 1e-5
warmup_target = 1e-3
warmup_steps = 10*train_generator.__len__()

lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=initial_learning_rate,
    decay_steps=decay_steps,
    alpha=alpha,
    warmup_target = warmup_target,
    warmup_steps = warmup_steps
)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Nadam(learning_rate=1e-3),
    loss=slim_sse_loss,  # Use slim SSE loss
    metrics=[slim_rmse_metric, x_mae_metric, y_mae_metric, cotBeta_mae_metric]  # Optional: add metrics
)

# %%
fingerprint = '%08x' % random.randrange(16**8)
os.makedirs("trained_models", exist_ok=True)
base_dir = f'./trained_models/model-{fingerprint}-checkpoints'
os.makedirs(base_dir, exist_ok=True)  
checkpoint_filepath = base_dir + '/weights.{epoch:02d}-t{loss:.2f}-v{val_loss:.2f}.hdf5'

# %%
checkpoint_filepath
# Out:
# './trained_models/model-38cfae2b-checkpoints/weights.{epoch:02d}-t{loss:.2f}-v{val_loss:.2f}.hdf5'

# %%
print(fingerprint)
# Out:
# 38cfae2b

# %%
from tensorflow.keras.callbacks import CSVLogger, EarlyStopping, ModelCheckpoint, Callback

early_stopping_patience = 50

class CustomModelCheckpoint(ModelCheckpoint):
    def on_epoch_end(self, epoch, logs=None):
        super().on_epoch_end(epoch, logs)
        checkpoints = [f for f in os.listdir(base_dir) if f.startswith('weights')]
        if len(checkpoints) > 1:
            checkpoints.sort()
            for checkpoint in checkpoints[:-1]:
                os.remove(os.path.join(base_dir, checkpoint))

es = EarlyStopping(patience=early_stopping_patience, restore_best_weights=True)

mcp = CustomModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_loss',
    save_best_only=True,
    save_freq='epoch',
    verbose=1
)

csv_logger = CSVLogger(f'{base_dir}/training_log.csv', append=True)

# %%
class NanMonitorCallback(tf.keras.callbacks.Callback):
    def on_batch_end(self, batch, logs=None):
        logs = logs or {}
        loss = logs.get('loss')
        if loss is not None:
            if np.isnan(loss) or np.isinf(loss):
                print('NaN loss detected, terminating training')
                self.model.stop_training = True
                
# Add this to your callbacks list
nan_monitor = NanMonitorCallback()
callbacks = [es, mcp, csv_logger, nan_monitor]

# %%
# Now use it in model.fit()
history = model.fit(
    x=train_generator,
    validation_data=validation_generator,
    callbacks=callbacks,
    epochs=1000,
    shuffle=False,
    verbose=1
)
# Out:
# Epoch 1/1000
# 2025-07-07 02:53:13.678932: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2025-07-07 02:53:13.752200: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2025-07-07 02:53:13.859790: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2025-07-07 02:53:14.283356: I external/local_xla/xla/service/service.cc:168] XLA service 0x7fb50e4cae50 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-07-07 02:53:14.283413: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA A100-PCIE-40GB MIG 1g.5gb, Compute Capability 8.0
# 2025-07-07 02:53:14.294738: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1751849594.413447  155164 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 69/71 [============================>.] - ETA: 0s - loss: 2774.0488 - slim_rmse_metric: 0.4237 - x_mae_metric: 0.3896 - y_mae_metric: 0.3627 - cotBeta_mae_metric: 0.3153
# Epoch 1: val_loss improved from inf to 1088.52759, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.01-t2728.77-v1088.53.hdf5
# 71/71 [==============================] - 10s 94ms/step - loss: 2728.7683 - slim_rmse_metric: 0.4196 - x_mae_metric: 0.3846 - y_mae_metric: 0.3587 - cotBeta_mae_metric: 0.3130 - val_loss: 1088.5276 - val_slim_rmse_metric: 0.2732 - val_x_mae_metric: 0.2083 - val_y_mae_metric: 0.2199 - val_cotBeta_mae_metric: 0.2268
# Epoch 2/1000
# 71/71 [==============================] - ETA: 0s - loss: 642.7905 - slim_rmse_metric: 0.2051 - x_mae_metric: 0.1511 - y_mae_metric: 0.1809 - cotBeta_mae_metric: 0.1300
# Epoch 2: val_loss improved from 1088.52759 to 504.99142, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.02-t642.79-v504.99.hdf5
# 71/71 [==============================] - 6s 87ms/step - loss: 642.7905 - slim_rmse_metric: 0.2051 - x_mae_metric: 0.1511 - y_mae_metric: 0.1809 - cotBeta_mae_metric: 0.1300 - val_loss: 504.9914 - val_slim_rmse_metric: 0.1855 - val_x_mae_metric: 0.1359 - val_y_mae_metric: 0.1666 - val_cotBeta_mae_metric: 0.1017
# Epoch 3/1000
# 71/71 [==============================] - ETA: 0s - loss: 491.2726 - slim_rmse_metric: 0.1804 - x_mae_metric: 0.1332 - y_mae_metric: 0.1617 - cotBeta_mae_metric: 0.0971
# Epoch 3: val_loss improved from 504.99142 to 468.03964, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.03-t491.27-v468.04.hdf5
# 71/71 [==============================] - 6s 84ms/step - loss: 491.2726 - slim_rmse_metric: 0.1804 - x_mae_metric: 0.1332 - y_mae_metric: 0.1617 - cotBeta_mae_metric: 0.0971 - val_loss: 468.0396 - val_slim_rmse_metric: 0.1786 - val_x_mae_metric: 0.1319 - val_y_mae_metric: 0.1591 - val_cotBeta_mae_metric: 0.0944
# Epoch 4/1000
# 71/71 [==============================] - ETA: 0s - loss: 451.1785 - slim_rmse_metric: 0.1728 - x_mae_metric: 0.1287 - y_mae_metric: 0.1532 - cotBeta_mae_metric: 0.0917
# Epoch 4: val_loss improved from 468.03964 to 419.08246, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.04-t451.18-v419.08.hdf5
# 71/71 [==============================] - 6s 83ms/step - loss: 451.1785 - slim_rmse_metric: 0.1728 - x_mae_metric: 0.1287 - y_mae_metric: 0.1532 - cotBeta_mae_metric: 0.0917 - val_loss: 419.0825 - val_slim_rmse_metric: 0.1689 - val_x_mae_metric: 0.1261 - val_y_mae_metric: 0.1475 - val_cotBeta_mae_metric: 0.0898
# Epoch 5/1000
# 71/71 [==============================] - ETA: 0s - loss: 390.3332 - slim_rmse_metric: 0.1606 - x_mae_metric: 0.1214 - y_mae_metric: 0.1371 - cotBeta_mae_metric: 0.0878
# Epoch 5: val_loss improved from 419.08246 to 351.38470, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.05-t390.33-v351.38.hdf5
# 71/71 [==============================] - 6s 84ms/step - loss: 390.3332 - slim_rmse_metric: 0.1606 - x_mae_metric: 0.1214 - y_mae_metric: 0.1371 - cotBeta_mae_metric: 0.0878 - val_loss: 351.3847 - val_slim_rmse_metric: 0.1545 - val_x_mae_metric: 0.1179 - val_y_mae_metric: 0.1267 - val_cotBeta_mae_metric: 0.0869
# Epoch 6/1000
# 71/71 [==============================] - ETA: 0s - loss: 322.9521 - slim_rmse_metric: 0.1459 - x_mae_metric: 0.1130 - y_mae_metric: 0.1145 - cotBeta_mae_metric: 0.0861
# Epoch 6: val_loss improved from 351.38470 to 290.14114, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.06-t322.95-v290.14.hdf5
# 71/71 [==============================] - 6s 79ms/step - loss: 322.9521 - slim_rmse_metric: 0.1459 - x_mae_metric: 0.1130 - y_mae_metric: 0.1145 - cotBeta_mae_metric: 0.0861 - val_loss: 290.1411 - val_slim_rmse_metric: 0.1402 - val_x_mae_metric: 0.1098 - val_y_mae_metric: 0.1042 - val_cotBeta_mae_metric: 0.0864
# Epoch 7/1000
# 71/71 [==============================] - ETA: 0s - loss: 274.6088 - slim_rmse_metric: 0.1344 - x_mae_metric: 0.1055 - y_mae_metric: 0.0978 - cotBeta_mae_metric: 0.0857
# Epoch 7: val_loss improved from 290.14114 to 254.38057, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.07-t274.61-v254.38.hdf5
# 71/71 [==============================] - 6s 84ms/step - loss: 274.6088 - slim_rmse_metric: 0.1344 - x_mae_metric: 0.1055 - y_mae_metric: 0.0978 - cotBeta_mae_metric: 0.0857 - val_loss: 254.3806 - val_slim_rmse_metric: 0.1311 - val_x_mae_metric: 0.1028 - val_y_mae_metric: 0.0930 - val_cotBeta_mae_metric: 0.0854
# Epoch 8/1000
# 71/71 [==============================] - ETA: 0s - loss: 246.0621 - slim_rmse_metric: 0.1271 - x_mae_metric: 0.0990 - y_mae_metric: 0.0903 - cotBeta_mae_metric: 0.0838
# Epoch 8: val_loss improved from 254.38057 to 231.13155, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.08-t246.06-v231.13.hdf5
# 71/71 [==============================] - 6s 83ms/step - loss: 246.0621 - slim_rmse_metric: 0.1271 - x_mae_metric: 0.0990 - y_mae_metric: 0.0903 - cotBeta_mae_metric: 0.0838 - val_loss: 231.1315 - val_slim_rmse_metric: 0.1249 - val_x_mae_metric: 0.0967 - val_y_mae_metric: 0.0875 - val_cotBeta_mae_metric: 0.0829
# Epoch 9/1000
# 71/71 [==============================] - ETA: 0s - loss: 225.7681 - slim_rmse_metric: 0.1216 - x_mae_metric: 0.0933 - y_mae_metric: 0.0858 - cotBeta_mae_metric: 0.0813
# Epoch 9: val_loss improved from 231.13155 to 213.99580, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.09-t225.77-v214.00.hdf5
# 71/71 [==============================] - 6s 83ms/step - loss: 225.7681 - slim_rmse_metric: 0.1216 - x_mae_metric: 0.0933 - y_mae_metric: 0.0858 - cotBeta_mae_metric: 0.0813 - val_loss: 213.9958 - val_slim_rmse_metric: 0.1201 - val_x_mae_metric: 0.0915 - val_y_mae_metric: 0.0837 - val_cotBeta_mae_metric: 0.0807
# Epoch 10/1000
# 71/71 [==============================] - ETA: 0s - loss: 210.7937 - slim_rmse_metric: 0.1174 - x_mae_metric: 0.0888 - y_mae_metric: 0.0824 - cotBeta_mae_metric: 0.0793
# Epoch 10: val_loss improved from 213.99580 to 201.55173, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.10-t210.79-v201.55.hdf5
# 71/71 [==============================] - 6s 82ms/step - loss: 210.7937 - slim_rmse_metric: 0.1174 - x_mae_metric: 0.0888 - y_mae_metric: 0.0824 - cotBeta_mae_metric: 0.0793 - val_loss: 201.5517 - val_slim_rmse_metric: 0.1164 - val_x_mae_metric: 0.0877 - val_y_mae_metric: 0.0807 - val_cotBeta_mae_metric: 0.0790
# Epoch 11/1000
# 71/71 [==============================] - ETA: 0s - loss: 199.8496 - slim_rmse_metric: 0.1142 - x_mae_metric: 0.0856 - y_mae_metric: 0.0798 - cotBeta_mae_metric: 0.0779
# Epoch 11: val_loss improved from 201.55173 to 192.37718, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.11-t199.85-v192.38.hdf5
# 71/71 [==============================] - 6s 84ms/step - loss: 199.8496 - slim_rmse_metric: 0.1142 - x_mae_metric: 0.0856 - y_mae_metric: 0.0798 - cotBeta_mae_metric: 0.0779 - val_loss: 192.3772 - val_slim_rmse_metric: 0.1137 - val_x_mae_metric: 0.0849 - val_y_mae_metric: 0.0784 - val_cotBeta_mae_metric: 0.0777
# Epoch 12/1000
# 71/71 [==============================] - ETA: 0s - loss: 191.5047 - slim_rmse_metric: 0.1117 - x_mae_metric: 0.0832 - y_mae_metric: 0.0777 - cotBeta_mae_metric: 0.0767
# Epoch 12: val_loss improved from 192.37718 to 185.13492, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.12-t191.50-v185.13.hdf5
# 71/71 [==============================] - 6s 82ms/step - loss: 191.5047 - slim_rmse_metric: 0.1117 - x_mae_metric: 0.0832 - y_mae_metric: 0.0777 - cotBeta_mae_metric: 0.0767 - val_loss: 185.1349 - val_slim_rmse_metric: 0.1115 - val_x_mae_metric: 0.0828 - val_y_mae_metric: 0.0766 - val_cotBeta_mae_metric: 0.0767
# Epoch 13/1000
# 71/71 [==============================] - ETA: 0s - loss: 184.6469 - slim_rmse_metric: 0.1097 - x_mae_metric: 0.0813 - y_mae_metric: 0.0760 - cotBeta_mae_metric: 0.0757
# Epoch 13: val_loss improved from 185.13492 to 178.99042, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.13-t184.65-v178.99.hdf5
# 71/71 [==============================] - 6s 82ms/step - loss: 184.6469 - slim_rmse_metric: 0.1097 - x_mae_metric: 0.0813 - y_mae_metric: 0.0760 - cotBeta_mae_metric: 0.0757 - val_loss: 178.9904 - val_slim_rmse_metric: 0.1095 - val_x_mae_metric: 0.0810 - val_y_mae_metric: 0.0751 - val_cotBeta_mae_metric: 0.0758
# Epoch 14/1000
# 71/71 [==============================] - ETA: 0s - loss: 178.6996 - slim_rmse_metric: 0.1078 - x_mae_metric: 0.0796 - y_mae_metric: 0.0746 - cotBeta_mae_metric: 0.0749
# Epoch 14: val_loss improved from 178.99042 to 173.60681, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.14-t178.70-v173.61.hdf5
# 71/71 [==============================] - 6s 84ms/step - loss: 178.6996 - slim_rmse_metric: 0.1078 - x_mae_metric: 0.0796 - y_mae_metric: 0.0746 - cotBeta_mae_metric: 0.0749 - val_loss: 173.6068 - val_slim_rmse_metric: 0.1078 - val_x_mae_metric: 0.0795 - val_y_mae_metric: 0.0739 - val_cotBeta_mae_metric: 0.0750
# Epoch 15/1000
# 71/71 [==============================] - ETA: 0s - loss: 173.4795 - slim_rmse_metric: 0.1062 - x_mae_metric: 0.0781 - y_mae_metric: 0.0734 - cotBeta_mae_metric: 0.0741
# Epoch 15: val_loss improved from 173.60681 to 168.90004, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.15-t173.48-v168.90.hdf5
# 71/71 [==============================] - 6s 82ms/step - loss: 173.4795 - slim_rmse_metric: 0.1062 - x_mae_metric: 0.0781 - y_mae_metric: 0.0734 - cotBeta_mae_metric: 0.0741 - val_loss: 168.9000 - val_slim_rmse_metric: 0.1063 - val_x_mae_metric: 0.0780 - val_y_mae_metric: 0.0729 - val_cotBeta_mae_metric: 0.0742
# Epoch 16/1000
# 71/71 [==============================] - ETA: 0s - loss: 168.9362 - slim_rmse_metric: 0.1047 - x_mae_metric: 0.0768 - y_mae_metric: 0.0725 - cotBeta_mae_metric: 0.0733
# Epoch 16: val_loss improved from 168.90004 to 164.81313, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.16-t168.94-v164.81.hdf5
# 71/71 [==============================] - 6s 84ms/step - loss: 168.9362 - slim_rmse_metric: 0.1047 - x_mae_metric: 0.0768 - y_mae_metric: 0.0725 - cotBeta_mae_metric: 0.0733 - val_loss: 164.8131 - val_slim_rmse_metric: 0.1049 - val_x_mae_metric: 0.0768 - val_y_mae_metric: 0.0721 - val_cotBeta_mae_metric: 0.0734
# Epoch 17/1000
# 71/71 [==============================] - ETA: 0s - loss: 164.9922 - slim_rmse_metric: 0.1034 - x_mae_metric: 0.0757 - y_mae_metric: 0.0717 - cotBeta_mae_metric: 0.0726
# Epoch 17: val_loss improved from 164.81313 to 161.23694, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.17-t164.99-v161.24.hdf5
# 71/71 [==============================] - 6s 85ms/step - loss: 164.9922 - slim_rmse_metric: 0.1034 - x_mae_metric: 0.0757 - y_mae_metric: 0.0717 - cotBeta_mae_metric: 0.0726 - val_loss: 161.2369 - val_slim_rmse_metric: 0.1037 - val_x_mae_metric: 0.0758 - val_y_mae_metric: 0.0714 - val_cotBeta_mae_metric: 0.0727
# Epoch 18/1000
# 71/71 [==============================] - ETA: 0s - loss: 161.5221 - slim_rmse_metric: 0.1023 - x_mae_metric: 0.0747 - y_mae_metric: 0.0711 - cotBeta_mae_metric: 0.0719
# Epoch 18: val_loss improved from 161.23694 to 158.04053, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.18-t161.52-v158.04.hdf5
# 71/71 [==============================] - 6s 81ms/step - loss: 161.5221 - slim_rmse_metric: 0.1023 - x_mae_metric: 0.0747 - y_mae_metric: 0.0711 - cotBeta_mae_metric: 0.0719 - val_loss: 158.0405 - val_slim_rmse_metric: 0.1027 - val_x_mae_metric: 0.0749 - val_y_mae_metric: 0.0708 - val_cotBeta_mae_metric: 0.0720
# Epoch 19/1000
# 71/71 [==============================] - ETA: 0s - loss: 158.3969 - slim_rmse_metric: 0.1013 - x_mae_metric: 0.0739 - y_mae_metric: 0.0705 - cotBeta_mae_metric: 0.0711
# Epoch 19: val_loss improved from 158.04053 to 155.11415, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.19-t158.40-v155.11.hdf5
# 71/71 [==============================] - 6s 82ms/step - loss: 158.3969 - slim_rmse_metric: 0.1013 - x_mae_metric: 0.0739 - y_mae_metric: 0.0705 - cotBeta_mae_metric: 0.0711 - val_loss: 155.1142 - val_slim_rmse_metric: 0.1017 - val_x_mae_metric: 0.0741 - val_y_mae_metric: 0.0703 - val_cotBeta_mae_metric: 0.0712
# Epoch 20/1000
# 71/71 [==============================] - ETA: 0s - loss: 155.5193 - slim_rmse_metric: 0.1003 - x_mae_metric: 0.0731 - y_mae_metric: 0.0701 - cotBeta_mae_metric: 0.0704
# Epoch 20: val_loss improved from 155.11415 to 152.38817, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.20-t155.52-v152.39.hdf5
# 71/71 [==============================] - 6s 82ms/step - loss: 155.5193 - slim_rmse_metric: 0.1003 - x_mae_metric: 0.0731 - y_mae_metric: 0.0701 - cotBeta_mae_metric: 0.0704 - val_loss: 152.3882 - val_slim_rmse_metric: 0.1007 - val_x_mae_metric: 0.0733 - val_y_mae_metric: 0.0699 - val_cotBeta_mae_metric: 0.0705
# Epoch 21/1000
# 71/71 [==============================] - ETA: 0s - loss: 152.8298 - slim_rmse_metric: 0.0994 - x_mae_metric: 0.0724 - y_mae_metric: 0.0696 - cotBeta_mae_metric: 0.0696
# Epoch 21: val_loss improved from 152.38817 to 149.82254, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.21-t152.83-v149.82.hdf5
# 71/71 [==============================] - 6s 84ms/step - loss: 152.8298 - slim_rmse_metric: 0.0994 - x_mae_metric: 0.0724 - y_mae_metric: 0.0696 - cotBeta_mae_metric: 0.0696 - val_loss: 149.8225 - val_slim_rmse_metric: 0.0998 - val_x_mae_metric: 0.0727 - val_y_mae_metric: 0.0695 - val_cotBeta_mae_metric: 0.0697
# Epoch 22/1000
# 71/71 [==============================] - ETA: 0s - loss: 150.2950 - slim_rmse_metric: 0.0985 - x_mae_metric: 0.0718 - y_mae_metric: 0.0692 - cotBeta_mae_metric: 0.0688
# Epoch 22: val_loss improved from 149.82254 to 147.39738, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.22-t150.30-v147.40.hdf5
# 71/71 [==============================] - 6s 86ms/step - loss: 150.2950 - slim_rmse_metric: 0.0985 - x_mae_metric: 0.0718 - y_mae_metric: 0.0692 - cotBeta_mae_metric: 0.0688 - val_loss: 147.3974 - val_slim_rmse_metric: 0.0990 - val_x_mae_metric: 0.0720 - val_y_mae_metric: 0.0692 - val_cotBeta_mae_metric: 0.0689
# Epoch 23/1000
# 71/71 [==============================] - ETA: 0s - loss: 147.8981 - slim_rmse_metric: 0.0977 - x_mae_metric: 0.0712 - y_mae_metric: 0.0688 - cotBeta_mae_metric: 0.0681
# Epoch 23: val_loss improved from 147.39738 to 145.10110, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.23-t147.90-v145.10.hdf5
# 71/71 [==============================] - 6s 83ms/step - loss: 147.8981 - slim_rmse_metric: 0.0977 - x_mae_metric: 0.0712 - y_mae_metric: 0.0688 - cotBeta_mae_metric: 0.0681 - val_loss: 145.1011 - val_slim_rmse_metric: 0.0982 - val_x_mae_metric: 0.0714 - val_y_mae_metric: 0.0688 - val_cotBeta_mae_metric: 0.0681
# Epoch 24/1000
# 71/71 [==============================] - ETA: 0s - loss: 145.6297 - slim_rmse_metric: 0.0969 - x_mae_metric: 0.0706 - y_mae_metric: 0.0685 - cotBeta_mae_metric: 0.0673
# Epoch 24: val_loss improved from 145.10110 to 142.92760, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.24-t145.63-v142.93.hdf5
# 71/71 [==============================] - 6s 86ms/step - loss: 145.6297 - slim_rmse_metric: 0.0969 - x_mae_metric: 0.0706 - y_mae_metric: 0.0685 - cotBeta_mae_metric: 0.0673 - val_loss: 142.9276 - val_slim_rmse_metric: 0.0974 - val_x_mae_metric: 0.0708 - val_y_mae_metric: 0.0685 - val_cotBeta_mae_metric: 0.0673
# Epoch 25/1000
# 71/71 [==============================] - ETA: 0s - loss: 143.4841 - slim_rmse_metric: 0.0962 - x_mae_metric: 0.0701 - y_mae_metric: 0.0682 - cotBeta_mae_metric: 0.0665
# Epoch 25: val_loss improved from 142.92760 to 140.87160, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.25-t143.48-v140.87.hdf5
# 71/71 [==============================] - 6s 83ms/step - loss: 143.4841 - slim_rmse_metric: 0.0962 - x_mae_metric: 0.0701 - y_mae_metric: 0.0682 - cotBeta_mae_metric: 0.0665 - val_loss: 140.8716 - val_slim_rmse_metric: 0.0967 - val_x_mae_metric: 0.0703 - val_y_mae_metric: 0.0683 - val_cotBeta_mae_metric: 0.0666
# Epoch 26/1000
# 71/71 [==============================] - ETA: 0s - loss: 141.4572 - slim_rmse_metric: 0.0954 - x_mae_metric: 0.0696 - y_mae_metric: 0.0679 - cotBeta_mae_metric: 0.0658
# Epoch 26: val_loss improved from 140.87160 to 138.92941, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.26-t141.46-v138.93.hdf5
# 71/71 [==============================] - 6s 85ms/step - loss: 141.4572 - slim_rmse_metric: 0.0954 - x_mae_metric: 0.0696 - y_mae_metric: 0.0679 - cotBeta_mae_metric: 0.0658 - val_loss: 138.9294 - val_slim_rmse_metric: 0.0960 - val_x_mae_metric: 0.0698 - val_y_mae_metric: 0.0681 - val_cotBeta_mae_metric: 0.0658
# Epoch 27/1000
# 71/71 [==============================] - ETA: 0s - loss: 139.5450 - slim_rmse_metric: 0.0948 - x_mae_metric: 0.0691 - y_mae_metric: 0.0677 - cotBeta_mae_metric: 0.0650
# Epoch 27: val_loss improved from 138.92941 to 137.09550, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.27-t139.54-v137.10.hdf5
# 71/71 [==============================] - 6s 85ms/step - loss: 139.5450 - slim_rmse_metric: 0.0948 - x_mae_metric: 0.0691 - y_mae_metric: 0.0677 - cotBeta_mae_metric: 0.0650 - val_loss: 137.0955 - val_slim_rmse_metric: 0.0953 - val_x_mae_metric: 0.0693 - val_y_mae_metric: 0.0678 - val_cotBeta_mae_metric: 0.0651
# Epoch 28/1000
# 71/71 [==============================] - ETA: 0s - loss: 137.7437 - slim_rmse_metric: 0.0941 - x_mae_metric: 0.0687 - y_mae_metric: 0.0674 - cotBeta_mae_metric: 0.0643
# Epoch 28: val_loss improved from 137.09550 to 135.36290, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.28-t137.74-v135.36.hdf5
# 71/71 [==============================] - 6s 83ms/step - loss: 137.7437 - slim_rmse_metric: 0.0941 - x_mae_metric: 0.0687 - y_mae_metric: 0.0674 - cotBeta_mae_metric: 0.0643 - val_loss: 135.3629 - val_slim_rmse_metric: 0.0946 - val_x_mae_metric: 0.0689 - val_y_mae_metric: 0.0676 - val_cotBeta_mae_metric: 0.0643
# Epoch 29/1000
# 71/71 [==============================] - ETA: 0s - loss: 136.0457 - slim_rmse_metric: 0.0935 - x_mae_metric: 0.0683 - y_mae_metric: 0.0672 - cotBeta_mae_metric: 0.0636
# Epoch 29: val_loss improved from 135.36290 to 133.72032, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.29-t136.05-v133.72.hdf5
# 71/71 [==============================] - 6s 84ms/step - loss: 136.0457 - slim_rmse_metric: 0.0935 - x_mae_metric: 0.0683 - y_mae_metric: 0.0672 - cotBeta_mae_metric: 0.0636 - val_loss: 133.7203 - val_slim_rmse_metric: 0.0940 - val_x_mae_metric: 0.0685 - val_y_mae_metric: 0.0675 - val_cotBeta_mae_metric: 0.0636
# Epoch 30/1000
# 71/71 [==============================] - ETA: 0s - loss: 134.4322 - slim_rmse_metric: 0.0929 - x_mae_metric: 0.0680 - y_mae_metric: 0.0670 - cotBeta_mae_metric: 0.0629
# Epoch 30: val_loss improved from 133.72032 to 132.15903, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.30-t134.43-v132.16.hdf5
# 71/71 [==============================] - 6s 84ms/step - loss: 134.4322 - slim_rmse_metric: 0.0929 - x_mae_metric: 0.0680 - y_mae_metric: 0.0670 - cotBeta_mae_metric: 0.0629 - val_loss: 132.1590 - val_slim_rmse_metric: 0.0935 - val_x_mae_metric: 0.0681 - val_y_mae_metric: 0.0673 - val_cotBeta_mae_metric: 0.0629
# Epoch 31/1000
# 71/71 [==============================] - ETA: 0s - loss: 132.8887 - slim_rmse_metric: 0.0923 - x_mae_metric: 0.0677 - y_mae_metric: 0.0668 - cotBeta_mae_metric: 0.0622
# Epoch 31: val_loss improved from 132.15903 to 130.66785, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.31-t132.89-v130.67.hdf5
# 71/71 [==============================] - 6s 81ms/step - loss: 132.8887 - slim_rmse_metric: 0.0923 - x_mae_metric: 0.0677 - y_mae_metric: 0.0668 - cotBeta_mae_metric: 0.0622 - val_loss: 130.6678 - val_slim_rmse_metric: 0.0929 - val_x_mae_metric: 0.0678 - val_y_mae_metric: 0.0671 - val_cotBeta_mae_metric: 0.0622
# Epoch 32/1000
# 71/71 [==============================] - ETA: 0s - loss: 131.4087 - slim_rmse_metric: 0.0918 - x_mae_metric: 0.0674 - y_mae_metric: 0.0667 - cotBeta_mae_metric: 0.0615
# Epoch 32: val_loss improved from 130.66785 to 129.23611, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.32-t131.41-v129.24.hdf5
# 71/71 [==============================] - 6s 80ms/step - loss: 131.4087 - slim_rmse_metric: 0.0918 - x_mae_metric: 0.0674 - y_mae_metric: 0.0667 - cotBeta_mae_metric: 0.0615 - val_loss: 129.2361 - val_slim_rmse_metric: 0.0924 - val_x_mae_metric: 0.0675 - val_y_mae_metric: 0.0670 - val_cotBeta_mae_metric: 0.0614
# Epoch 33/1000
# 71/71 [==============================] - ETA: 0s - loss: 129.9792 - slim_rmse_metric: 0.0913 - x_mae_metric: 0.0671 - y_mae_metric: 0.0665 - cotBeta_mae_metric: 0.0607
# Epoch 33: val_loss improved from 129.23611 to 127.85051, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.33-t129.98-v127.85.hdf5
# 71/71 [==============================] - 6s 81ms/step - loss: 129.9792 - slim_rmse_metric: 0.0913 - x_mae_metric: 0.0671 - y_mae_metric: 0.0665 - cotBeta_mae_metric: 0.0607 - val_loss: 127.8505 - val_slim_rmse_metric: 0.0918 - val_x_mae_metric: 0.0672 - val_y_mae_metric: 0.0668 - val_cotBeta_mae_metric: 0.0607
# Epoch 34/1000
# 71/71 [==============================] - ETA: 0s - loss: 128.5887 - slim_rmse_metric: 0.0907 - x_mae_metric: 0.0668 - y_mae_metric: 0.0663 - cotBeta_mae_metric: 0.0600
# Epoch 34: val_loss improved from 127.85051 to 126.49979, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.34-t128.59-v126.50.hdf5
# 71/71 [==============================] - 6s 85ms/step - loss: 128.5887 - slim_rmse_metric: 0.0907 - x_mae_metric: 0.0668 - y_mae_metric: 0.0663 - cotBeta_mae_metric: 0.0600 - val_loss: 126.4998 - val_slim_rmse_metric: 0.0913 - val_x_mae_metric: 0.0669 - val_y_mae_metric: 0.0667 - val_cotBeta_mae_metric: 0.0599
# Epoch 35/1000
# 71/71 [==============================] - ETA: 0s - loss: 127.2267 - slim_rmse_metric: 0.0902 - x_mae_metric: 0.0666 - y_mae_metric: 0.0662 - cotBeta_mae_metric: 0.0592
# Epoch 35: val_loss improved from 126.49979 to 125.17625, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.35-t127.23-v125.18.hdf5
# 71/71 [==============================] - 6s 84ms/step - loss: 127.2267 - slim_rmse_metric: 0.0902 - x_mae_metric: 0.0666 - y_mae_metric: 0.0662 - cotBeta_mae_metric: 0.0592 - val_loss: 125.1763 - val_slim_rmse_metric: 0.0908 - val_x_mae_metric: 0.0667 - val_y_mae_metric: 0.0665 - val_cotBeta_mae_metric: 0.0591
# Epoch 36/1000
# 71/71 [==============================] - ETA: 0s - loss: 125.8861 - slim_rmse_metric: 0.0897 - x_mae_metric: 0.0664 - y_mae_metric: 0.0660 - cotBeta_mae_metric: 0.0584
# Epoch 36: val_loss improved from 125.17625 to 123.87203, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.36-t125.89-v123.87.hdf5
# 71/71 [==============================] - 6s 83ms/step - loss: 125.8861 - slim_rmse_metric: 0.0897 - x_mae_metric: 0.0664 - y_mae_metric: 0.0660 - cotBeta_mae_metric: 0.0584 - val_loss: 123.8720 - val_slim_rmse_metric: 0.0903 - val_x_mae_metric: 0.0665 - val_y_mae_metric: 0.0664 - val_cotBeta_mae_metric: 0.0583
# Epoch 37/1000
# 71/71 [==============================] - ETA: 0s - loss: 124.5606 - slim_rmse_metric: 0.0892 - x_mae_metric: 0.0662 - y_mae_metric: 0.0658 - cotBeta_mae_metric: 0.0575
# Epoch 37: val_loss improved from 123.87203 to 122.58399, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.37-t124.56-v122.58.hdf5
# 71/71 [==============================] - 6s 84ms/step - loss: 124.5606 - slim_rmse_metric: 0.0892 - x_mae_metric: 0.0662 - y_mae_metric: 0.0658 - cotBeta_mae_metric: 0.0575 - val_loss: 122.5840 - val_slim_rmse_metric: 0.0898 - val_x_mae_metric: 0.0663 - val_y_mae_metric: 0.0662 - val_cotBeta_mae_metric: 0.0574
# Epoch 38/1000
# 71/71 [==============================] - ETA: 0s - loss: 123.2483 - slim_rmse_metric: 0.0887 - x_mae_metric: 0.0660 - y_mae_metric: 0.0657 - cotBeta_mae_metric: 0.0566
# Epoch 38: val_loss improved from 122.58399 to 121.31163, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.38-t123.25-v121.31.hdf5
# 71/71 [==============================] - 6s 83ms/step - loss: 123.2483 - slim_rmse_metric: 0.0887 - x_mae_metric: 0.0660 - y_mae_metric: 0.0657 - cotBeta_mae_metric: 0.0566 - val_loss: 121.3116 - val_slim_rmse_metric: 0.0893 - val_x_mae_metric: 0.0661 - val_y_mae_metric: 0.0660 - val_cotBeta_mae_metric: 0.0565
# Epoch 39/1000
# 71/71 [==============================] - ETA: 0s - loss: 121.9494 - slim_rmse_metric: 0.0882 - x_mae_metric: 0.0658 - y_mae_metric: 0.0655 - cotBeta_mae_metric: 0.0557
# Epoch 39: val_loss improved from 121.31163 to 120.05689, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.39-t121.95-v120.06.hdf5
# 71/71 [==============================] - 6s 85ms/step - loss: 121.9494 - slim_rmse_metric: 0.0882 - x_mae_metric: 0.0658 - y_mae_metric: 0.0655 - cotBeta_mae_metric: 0.0557 - val_loss: 120.0569 - val_slim_rmse_metric: 0.0888 - val_x_mae_metric: 0.0659 - val_y_mae_metric: 0.0659 - val_cotBeta_mae_metric: 0.0555
# Epoch 40/1000
# 71/71 [==============================] - ETA: 0s - loss: 120.6666 - slim_rmse_metric: 0.0877 - x_mae_metric: 0.0656 - y_mae_metric: 0.0653 - cotBeta_mae_metric: 0.0547
# Epoch 40: val_loss improved from 120.05689 to 118.82523, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.40-t120.67-v118.83.hdf5
# 71/71 [==============================] - 6s 84ms/step - loss: 120.6666 - slim_rmse_metric: 0.0877 - x_mae_metric: 0.0656 - y_mae_metric: 0.0653 - cotBeta_mae_metric: 0.0547 - val_loss: 118.8252 - val_slim_rmse_metric: 0.0883 - val_x_mae_metric: 0.0657 - val_y_mae_metric: 0.0657 - val_cotBeta_mae_metric: 0.0545
# Epoch 41/1000
# 71/71 [==============================] - ETA: 0s - loss: 119.4066 - slim_rmse_metric: 0.0873 - x_mae_metric: 0.0655 - y_mae_metric: 0.0652 - cotBeta_mae_metric: 0.0537
# Epoch 41: val_loss improved from 118.82523 to 117.62477, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.41-t119.41-v117.62.hdf5
# 71/71 [==============================] - 6s 85ms/step - loss: 119.4066 - slim_rmse_metric: 0.0873 - x_mae_metric: 0.0655 - y_mae_metric: 0.0652 - cotBeta_mae_metric: 0.0537 - val_loss: 117.6248 - val_slim_rmse_metric: 0.0879 - val_x_mae_metric: 0.0656 - val_y_mae_metric: 0.0656 - val_cotBeta_mae_metric: 0.0535
# Epoch 42/1000
# 71/71 [==============================] - ETA: 0s - loss: 118.1798 - slim_rmse_metric: 0.0868 - x_mae_metric: 0.0653 - y_mae_metric: 0.0650 - cotBeta_mae_metric: 0.0527
# Epoch 42: val_loss improved from 117.62477 to 116.46768, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.42-t118.18-v116.47.hdf5
# 71/71 [==============================] - 6s 83ms/step - loss: 118.1798 - slim_rmse_metric: 0.0868 - x_mae_metric: 0.0653 - y_mae_metric: 0.0650 - cotBeta_mae_metric: 0.0527 - val_loss: 116.4677 - val_slim_rmse_metric: 0.0874 - val_x_mae_metric: 0.0654 - val_y_mae_metric: 0.0654 - val_cotBeta_mae_metric: 0.0525
# Epoch 43/1000
# 71/71 [==============================] - ETA: 0s - loss: 116.9967 - slim_rmse_metric: 0.0863 - x_mae_metric: 0.0652 - y_mae_metric: 0.0648 - cotBeta_mae_metric: 0.0517
# Epoch 43: val_loss improved from 116.46768 to 115.36418, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.43-t117.00-v115.36.hdf5
# 71/71 [==============================] - 6s 85ms/step - loss: 116.9967 - slim_rmse_metric: 0.0863 - x_mae_metric: 0.0652 - y_mae_metric: 0.0648 - cotBeta_mae_metric: 0.0517 - val_loss: 115.3642 - val_slim_rmse_metric: 0.0870 - val_x_mae_metric: 0.0653 - val_y_mae_metric: 0.0653 - val_cotBeta_mae_metric: 0.0515
# Epoch 44/1000
# 71/71 [==============================] - ETA: 0s - loss: 115.8698 - slim_rmse_metric: 0.0859 - x_mae_metric: 0.0650 - y_mae_metric: 0.0647 - cotBeta_mae_metric: 0.0507
# Epoch 44: val_loss improved from 115.36418 to 114.32507, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.44-t115.87-v114.33.hdf5
# 71/71 [==============================] - 6s 83ms/step - loss: 115.8698 - slim_rmse_metric: 0.0859 - x_mae_metric: 0.0650 - y_mae_metric: 0.0647 - cotBeta_mae_metric: 0.0507 - val_loss: 114.3251 - val_slim_rmse_metric: 0.0865 - val_x_mae_metric: 0.0652 - val_y_mae_metric: 0.0651 - val_cotBeta_mae_metric: 0.0506
# Epoch 45/1000
# 71/71 [==============================] - ETA: 0s - loss: 114.8092 - slim_rmse_metric: 0.0855 - x_mae_metric: 0.0649 - y_mae_metric: 0.0645 - cotBeta_mae_metric: 0.0498
# Epoch 45: val_loss improved from 114.32507 to 113.35637, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.45-t114.81-v113.36.hdf5
# 71/71 [==============================] - 6s 83ms/step - loss: 114.8092 - slim_rmse_metric: 0.0855 - x_mae_metric: 0.0649 - y_mae_metric: 0.0645 - cotBeta_mae_metric: 0.0498 - val_loss: 113.3564 - val_slim_rmse_metric: 0.0862 - val_x_mae_metric: 0.0650 - val_y_mae_metric: 0.0649 - val_cotBeta_mae_metric: 0.0497
# Epoch 46/1000
# 71/71 [==============================] - ETA: 0s - loss: 113.8192 - slim_rmse_metric: 0.0851 - x_mae_metric: 0.0647 - y_mae_metric: 0.0644 - cotBeta_mae_metric: 0.0490
# Epoch 46: val_loss improved from 113.35637 to 112.45847, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.46-t113.82-v112.46.hdf5
# 71/71 [==============================] - 6s 82ms/step - loss: 113.8192 - slim_rmse_metric: 0.0851 - x_mae_metric: 0.0647 - y_mae_metric: 0.0644 - cotBeta_mae_metric: 0.0490 - val_loss: 112.4585 - val_slim_rmse_metric: 0.0858 - val_x_mae_metric: 0.0649 - val_y_mae_metric: 0.0648 - val_cotBeta_mae_metric: 0.0489
# Epoch 47/1000
# 71/71 [==============================] - ETA: 0s - loss: 112.9003 - slim_rmse_metric: 0.0847 - x_mae_metric: 0.0646 - y_mae_metric: 0.0642 - cotBeta_mae_metric: 0.0482
# Epoch 47: val_loss improved from 112.45847 to 111.62740, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.47-t112.90-v111.63.hdf5
# 71/71 [==============================] - 6s 81ms/step - loss: 112.9003 - slim_rmse_metric: 0.0847 - x_mae_metric: 0.0646 - y_mae_metric: 0.0642 - cotBeta_mae_metric: 0.0482 - val_loss: 111.6274 - val_slim_rmse_metric: 0.0855 - val_x_mae_metric: 0.0648 - val_y_mae_metric: 0.0646 - val_cotBeta_mae_metric: 0.0482
# Epoch 48/1000
# 71/71 [==============================] - ETA: 0s - loss: 112.0475 - slim_rmse_metric: 0.0844 - x_mae_metric: 0.0645 - y_mae_metric: 0.0640 - cotBeta_mae_metric: 0.0475
# Epoch 48: val_loss improved from 111.62740 to 110.85737, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.48-t112.05-v110.86.hdf5
# 71/71 [==============================] - 6s 81ms/step - loss: 112.0475 - slim_rmse_metric: 0.0844 - x_mae_metric: 0.0645 - y_mae_metric: 0.0640 - cotBeta_mae_metric: 0.0475 - val_loss: 110.8574 - val_slim_rmse_metric: 0.0851 - val_x_mae_metric: 0.0646 - val_y_mae_metric: 0.0645 - val_cotBeta_mae_metric: 0.0476
# Epoch 49/1000
# 71/71 [==============================] - ETA: 0s - loss: 111.2567 - slim_rmse_metric: 0.0840 - x_mae_metric: 0.0644 - y_mae_metric: 0.0639 - cotBeta_mae_metric: 0.0469
# Epoch 49: val_loss improved from 110.85737 to 110.14259, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.49-t111.26-v110.14.hdf5
# 71/71 [==============================] - 6s 84ms/step - loss: 111.2567 - slim_rmse_metric: 0.0840 - x_mae_metric: 0.0644 - y_mae_metric: 0.0639 - cotBeta_mae_metric: 0.0469 - val_loss: 110.1426 - val_slim_rmse_metric: 0.0849 - val_x_mae_metric: 0.0645 - val_y_mae_metric: 0.0643 - val_cotBeta_mae_metric: 0.0470
# Epoch 50/1000
# 71/71 [==============================] - ETA: 0s - loss: 110.5194 - slim_rmse_metric: 0.0838 - x_mae_metric: 0.0643 - y_mae_metric: 0.0637 - cotBeta_mae_metric: 0.0463
# Epoch 50: val_loss improved from 110.14259 to 109.47544, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.50-t110.52-v109.48.hdf5
# 71/71 [==============================] - 6s 84ms/step - loss: 110.5194 - slim_rmse_metric: 0.0838 - x_mae_metric: 0.0643 - y_mae_metric: 0.0637 - cotBeta_mae_metric: 0.0463 - val_loss: 109.4754 - val_slim_rmse_metric: 0.0846 - val_x_mae_metric: 0.0644 - val_y_mae_metric: 0.0642 - val_cotBeta_mae_metric: 0.0465
# Epoch 51/1000
# 71/71 [==============================] - ETA: 0s - loss: 109.8304 - slim_rmse_metric: 0.0835 - x_mae_metric: 0.0642 - y_mae_metric: 0.0636 - cotBeta_mae_metric: 0.0458
# Epoch 51: val_loss improved from 109.47544 to 108.85363, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.51-t109.83-v108.85.hdf5
# 71/71 [==============================] - 6s 86ms/step - loss: 109.8304 - slim_rmse_metric: 0.0835 - x_mae_metric: 0.0642 - y_mae_metric: 0.0636 - cotBeta_mae_metric: 0.0458 - val_loss: 108.8536 - val_slim_rmse_metric: 0.0843 - val_x_mae_metric: 0.0643 - val_y_mae_metric: 0.0640 - val_cotBeta_mae_metric: 0.0460
# Epoch 52/1000
# 71/71 [==============================] - ETA: 0s - loss: 109.1793 - slim_rmse_metric: 0.0832 - x_mae_metric: 0.0641 - y_mae_metric: 0.0635 - cotBeta_mae_metric: 0.0454
# Epoch 52: val_loss improved from 108.85363 to 108.27191, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.52-t109.18-v108.27.hdf5
# 71/71 [==============================] - 6s 83ms/step - loss: 109.1793 - slim_rmse_metric: 0.0832 - x_mae_metric: 0.0641 - y_mae_metric: 0.0635 - cotBeta_mae_metric: 0.0454 - val_loss: 108.2719 - val_slim_rmse_metric: 0.0841 - val_x_mae_metric: 0.0642 - val_y_mae_metric: 0.0639 - val_cotBeta_mae_metric: 0.0456
# Epoch 53/1000
# 71/71 [==============================] - ETA: 0s - loss: 108.5663 - slim_rmse_metric: 0.0830 - x_mae_metric: 0.0639 - y_mae_metric: 0.0633 - cotBeta_mae_metric: 0.0450
# Epoch 53: val_loss improved from 108.27191 to 107.75462, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.53-t108.57-v107.75.hdf5
# 71/71 [==============================] - 6s 83ms/step - loss: 108.5663 - slim_rmse_metric: 0.0830 - x_mae_metric: 0.0639 - y_mae_metric: 0.0633 - cotBeta_mae_metric: 0.0450 - val_loss: 107.7546 - val_slim_rmse_metric: 0.0839 - val_x_mae_metric: 0.0641 - val_y_mae_metric: 0.0638 - val_cotBeta_mae_metric: 0.0452
# Epoch 54/1000
# 71/71 [==============================] - ETA: 0s - loss: 108.1646 - slim_rmse_metric: 0.0828 - x_mae_metric: 0.0640 - y_mae_metric: 0.0632 - cotBeta_mae_metric: 0.0447
# Epoch 54: val_loss improved from 107.75462 to 107.38212, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.54-t108.16-v107.38.hdf5
# 71/71 [==============================] - 6s 82ms/step - loss: 108.1646 - slim_rmse_metric: 0.0828 - x_mae_metric: 0.0640 - y_mae_metric: 0.0632 - cotBeta_mae_metric: 0.0447 - val_loss: 107.3821 - val_slim_rmse_metric: 0.0837 - val_x_mae_metric: 0.0644 - val_y_mae_metric: 0.0636 - val_cotBeta_mae_metric: 0.0448
# Epoch 55/1000
# 71/71 [==============================] - ETA: 0s - loss: 107.5912 - slim_rmse_metric: 0.0826 - x_mae_metric: 0.0639 - y_mae_metric: 0.0631 - cotBeta_mae_metric: 0.0443
# Epoch 55: val_loss improved from 107.38212 to 106.68420, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.55-t107.59-v106.68.hdf5
# 71/71 [==============================] - 6s 84ms/step - loss: 107.5912 - slim_rmse_metric: 0.0826 - x_mae_metric: 0.0639 - y_mae_metric: 0.0631 - cotBeta_mae_metric: 0.0443 - val_loss: 106.6842 - val_slim_rmse_metric: 0.0834 - val_x_mae_metric: 0.0639 - val_y_mae_metric: 0.0635 - val_cotBeta_mae_metric: 0.0445
# Epoch 56/1000
# 71/71 [==============================] - ETA: 0s - loss: 106.9626 - slim_rmse_metric: 0.0823 - x_mae_metric: 0.0636 - y_mae_metric: 0.0630 - cotBeta_mae_metric: 0.0440
# Epoch 56: val_loss improved from 106.68420 to 106.16469, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.56-t106.96-v106.16.hdf5
# 71/71 [==============================] - 6s 86ms/step - loss: 106.9626 - slim_rmse_metric: 0.0823 - x_mae_metric: 0.0636 - y_mae_metric: 0.0630 - cotBeta_mae_metric: 0.0440 - val_loss: 106.1647 - val_slim_rmse_metric: 0.0832 - val_x_mae_metric: 0.0639 - val_y_mae_metric: 0.0634 - val_cotBeta_mae_metric: 0.0442
# Epoch 57/1000
# 71/71 [==============================] - ETA: 0s - loss: 106.4640 - slim_rmse_metric: 0.0821 - x_mae_metric: 0.0635 - y_mae_metric: 0.0629 - cotBeta_mae_metric: 0.0437
# Epoch 57: val_loss improved from 106.16469 to 105.72047, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.57-t106.46-v105.72.hdf5
# 71/71 [==============================] - 6s 84ms/step - loss: 106.4640 - slim_rmse_metric: 0.0821 - x_mae_metric: 0.0635 - y_mae_metric: 0.0629 - cotBeta_mae_metric: 0.0437 - val_loss: 105.7205 - val_slim_rmse_metric: 0.0830 - val_x_mae_metric: 0.0638 - val_y_mae_metric: 0.0633 - val_cotBeta_mae_metric: 0.0439
# Epoch 58/1000
# 71/71 [==============================] - ETA: 0s - loss: 106.0025 - slim_rmse_metric: 0.0819 - x_mae_metric: 0.0635 - y_mae_metric: 0.0628 - cotBeta_mae_metric: 0.0434
# Epoch 58: val_loss improved from 105.72047 to 105.29939, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.58-t106.00-v105.30.hdf5
# 71/71 [==============================] - 6s 83ms/step - loss: 106.0025 - slim_rmse_metric: 0.0819 - x_mae_metric: 0.0635 - y_mae_metric: 0.0628 - cotBeta_mae_metric: 0.0434 - val_loss: 105.2994 - val_slim_rmse_metric: 0.0829 - val_x_mae_metric: 0.0637 - val_y_mae_metric: 0.0632 - val_cotBeta_mae_metric: 0.0436
# Epoch 59/1000
# 71/71 [==============================] - ETA: 0s - loss: 105.5645 - slim_rmse_metric: 0.0817 - x_mae_metric: 0.0634 - y_mae_metric: 0.0627 - cotBeta_mae_metric: 0.0431
# Epoch 59: val_loss improved from 105.29939 to 104.99776, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.59-t105.56-v105.00.hdf5
# 71/71 [==============================] - 6s 81ms/step - loss: 105.5645 - slim_rmse_metric: 0.0817 - x_mae_metric: 0.0634 - y_mae_metric: 0.0627 - cotBeta_mae_metric: 0.0431 - val_loss: 104.9978 - val_slim_rmse_metric: 0.0827 - val_x_mae_metric: 0.0636 - val_y_mae_metric: 0.0632 - val_cotBeta_mae_metric: 0.0435
# Epoch 60/1000
# 71/71 [==============================] - ETA: 0s - loss: 105.5608 - slim_rmse_metric: 0.0817 - x_mae_metric: 0.0635 - y_mae_metric: 0.0627 - cotBeta_mae_metric: 0.0430
# Epoch 60: val_loss improved from 104.99776 to 104.45454, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.60-t105.56-v104.45.hdf5
# 71/71 [==============================] - 6s 82ms/step - loss: 105.5608 - slim_rmse_metric: 0.0817 - x_mae_metric: 0.0635 - y_mae_metric: 0.0627 - cotBeta_mae_metric: 0.0430 - val_loss: 104.4545 - val_slim_rmse_metric: 0.0825 - val_x_mae_metric: 0.0636 - val_y_mae_metric: 0.0629 - val_cotBeta_mae_metric: 0.0431
# Epoch 61/1000
# 71/71 [==============================] - ETA: 0s - loss: 104.6961 - slim_rmse_metric: 0.0814 - x_mae_metric: 0.0632 - y_mae_metric: 0.0625 - cotBeta_mae_metric: 0.0427
# Epoch 61: val_loss improved from 104.45454 to 104.11714, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.61-t104.70-v104.12.hdf5
# 71/71 [==============================] - 6s 84ms/step - loss: 104.6961 - slim_rmse_metric: 0.0814 - x_mae_metric: 0.0632 - y_mae_metric: 0.0625 - cotBeta_mae_metric: 0.0427 - val_loss: 104.1171 - val_slim_rmse_metric: 0.0824 - val_x_mae_metric: 0.0634 - val_y_mae_metric: 0.0629 - val_cotBeta_mae_metric: 0.0429
# Epoch 62/1000
# 71/71 [==============================] - ETA: 0s - loss: 104.3242 - slim_rmse_metric: 0.0812 - x_mae_metric: 0.0631 - y_mae_metric: 0.0624 - cotBeta_mae_metric: 0.0424
# Epoch 62: val_loss improved from 104.11714 to 103.73977, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.62-t104.32-v103.74.hdf5
# 71/71 [==============================] - 6s 81ms/step - loss: 104.3242 - slim_rmse_metric: 0.0812 - x_mae_metric: 0.0631 - y_mae_metric: 0.0624 - cotBeta_mae_metric: 0.0424 - val_loss: 103.7398 - val_slim_rmse_metric: 0.0822 - val_x_mae_metric: 0.0633 - val_y_mae_metric: 0.0628 - val_cotBeta_mae_metric: 0.0427
# Epoch 63/1000
# 71/71 [==============================] - ETA: 0s - loss: 103.9918 - slim_rmse_metric: 0.0811 - x_mae_metric: 0.0630 - y_mae_metric: 0.0623 - cotBeta_mae_metric: 0.0422
# Epoch 63: val_loss improved from 103.73977 to 103.56295, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.63-t103.99-v103.56.hdf5
# 71/71 [==============================] - 6s 83ms/step - loss: 103.9918 - slim_rmse_metric: 0.0811 - x_mae_metric: 0.0630 - y_mae_metric: 0.0623 - cotBeta_mae_metric: 0.0422 - val_loss: 103.5630 - val_slim_rmse_metric: 0.0821 - val_x_mae_metric: 0.0633 - val_y_mae_metric: 0.0629 - val_cotBeta_mae_metric: 0.0426
# Epoch 64/1000
# 71/71 [==============================] - ETA: 0s - loss: 103.9460 - slim_rmse_metric: 0.0811 - x_mae_metric: 0.0632 - y_mae_metric: 0.0624 - cotBeta_mae_metric: 0.0421
# Epoch 64: val_loss improved from 103.56295 to 103.06647, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.64-t103.95-v103.07.hdf5
# 71/71 [==============================] - 6s 87ms/step - loss: 103.9460 - slim_rmse_metric: 0.0811 - x_mae_metric: 0.0632 - y_mae_metric: 0.0624 - cotBeta_mae_metric: 0.0421 - val_loss: 103.0665 - val_slim_rmse_metric: 0.0819 - val_x_mae_metric: 0.0633 - val_y_mae_metric: 0.0626 - val_cotBeta_mae_metric: 0.0422
# Epoch 65/1000
# 71/71 [==============================] - ETA: 0s - loss: 103.2884 - slim_rmse_metric: 0.0808 - x_mae_metric: 0.0629 - y_mae_metric: 0.0622 - cotBeta_mae_metric: 0.0418
# Epoch 65: val_loss improved from 103.06647 to 102.76882, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.65-t103.29-v102.77.hdf5
# 71/71 [==============================] - 6s 84ms/step - loss: 103.2884 - slim_rmse_metric: 0.0808 - x_mae_metric: 0.0629 - y_mae_metric: 0.0622 - cotBeta_mae_metric: 0.0418 - val_loss: 102.7688 - val_slim_rmse_metric: 0.0818 - val_x_mae_metric: 0.0631 - val_y_mae_metric: 0.0626 - val_cotBeta_mae_metric: 0.0421
# Epoch 66/1000
# 71/71 [==============================] - ETA: 0s - loss: 102.9392 - slim_rmse_metric: 0.0807 - x_mae_metric: 0.0628 - y_mae_metric: 0.0621 - cotBeta_mae_metric: 0.0416
# Epoch 66: val_loss improved from 102.76882 to 102.42877, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.66-t102.94-v102.43.hdf5
# 71/71 [==============================] - 6s 81ms/step - loss: 102.9392 - slim_rmse_metric: 0.0807 - x_mae_metric: 0.0628 - y_mae_metric: 0.0621 - cotBeta_mae_metric: 0.0416 - val_loss: 102.4288 - val_slim_rmse_metric: 0.0816 - val_x_mae_metric: 0.0630 - val_y_mae_metric: 0.0625 - val_cotBeta_mae_metric: 0.0419
# Epoch 67/1000
# 71/71 [==============================] - ETA: 0s - loss: 102.7867 - slim_rmse_metric: 0.0806 - x_mae_metric: 0.0629 - y_mae_metric: 0.0621 - cotBeta_mae_metric: 0.0414
# Epoch 67: val_loss did not improve from 102.42877
# 71/71 [==============================] - 6s 83ms/step - loss: 102.7867 - slim_rmse_metric: 0.0806 - x_mae_metric: 0.0629 - y_mae_metric: 0.0621 - cotBeta_mae_metric: 0.0414 - val_loss: 102.9574 - val_slim_rmse_metric: 0.0819 - val_x_mae_metric: 0.0635 - val_y_mae_metric: 0.0628 - val_cotBeta_mae_metric: 0.0420
# Epoch 68/1000
# 71/71 [==============================] - ETA: 0s - loss: 102.5396 - slim_rmse_metric: 0.0805 - x_mae_metric: 0.0627 - y_mae_metric: 0.0621 - cotBeta_mae_metric: 0.0413
# Epoch 68: val_loss improved from 102.42877 to 101.77449, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.68-t102.54-v101.77.hdf5
# 71/71 [==============================] - 6s 86ms/step - loss: 102.5396 - slim_rmse_metric: 0.0805 - x_mae_metric: 0.0627 - y_mae_metric: 0.0621 - cotBeta_mae_metric: 0.0413 - val_loss: 101.7745 - val_slim_rmse_metric: 0.0814 - val_x_mae_metric: 0.0629 - val_y_mae_metric: 0.0623 - val_cotBeta_mae_metric: 0.0415
# Epoch 69/1000
# 71/71 [==============================] - ETA: 0s - loss: 102.0783 - slim_rmse_metric: 0.0803 - x_mae_metric: 0.0627 - y_mae_metric: 0.0619 - cotBeta_mae_metric: 0.0411
# Epoch 69: val_loss improved from 101.77449 to 101.68269, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.69-t102.08-v101.68.hdf5
# 71/71 [==============================] - 6s 85ms/step - loss: 102.0783 - slim_rmse_metric: 0.0803 - x_mae_metric: 0.0627 - y_mae_metric: 0.0619 - cotBeta_mae_metric: 0.0411 - val_loss: 101.6827 - val_slim_rmse_metric: 0.0813 - val_x_mae_metric: 0.0629 - val_y_mae_metric: 0.0624 - val_cotBeta_mae_metric: 0.0414
# Epoch 70/1000
# 71/71 [==============================] - ETA: 0s - loss: 101.7452 - slim_rmse_metric: 0.0802 - x_mae_metric: 0.0625 - y_mae_metric: 0.0619 - cotBeta_mae_metric: 0.0409
# Epoch 70: val_loss improved from 101.68269 to 101.24009, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.70-t101.75-v101.24.hdf5
# 71/71 [==============================] - 6s 81ms/step - loss: 101.7452 - slim_rmse_metric: 0.0802 - x_mae_metric: 0.0625 - y_mae_metric: 0.0619 - cotBeta_mae_metric: 0.0409 - val_loss: 101.2401 - val_slim_rmse_metric: 0.0811 - val_x_mae_metric: 0.0628 - val_y_mae_metric: 0.0622 - val_cotBeta_mae_metric: 0.0412
# Epoch 71/1000
# 71/71 [==============================] - ETA: 0s - loss: 101.8263 - slim_rmse_metric: 0.0802 - x_mae_metric: 0.0628 - y_mae_metric: 0.0619 - cotBeta_mae_metric: 0.0408
# Epoch 71: val_loss improved from 101.24009 to 101.15287, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.71-t101.83-v101.15.hdf5
# 71/71 [==============================] - 6s 84ms/step - loss: 101.8263 - slim_rmse_metric: 0.0802 - x_mae_metric: 0.0628 - y_mae_metric: 0.0619 - cotBeta_mae_metric: 0.0408 - val_loss: 101.1529 - val_slim_rmse_metric: 0.0811 - val_x_mae_metric: 0.0628 - val_y_mae_metric: 0.0623 - val_cotBeta_mae_metric: 0.0411
# Epoch 72/1000
# 71/71 [==============================] - ETA: 0s - loss: 101.1942 - slim_rmse_metric: 0.0799 - x_mae_metric: 0.0624 - y_mae_metric: 0.0618 - cotBeta_mae_metric: 0.0406
# Epoch 72: val_loss improved from 101.15287 to 100.74181, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.72-t101.19-v100.74.hdf5
# 71/71 [==============================] - 6s 83ms/step - loss: 101.1942 - slim_rmse_metric: 0.0799 - x_mae_metric: 0.0624 - y_mae_metric: 0.0618 - cotBeta_mae_metric: 0.0406 - val_loss: 100.7418 - val_slim_rmse_metric: 0.0809 - val_x_mae_metric: 0.0626 - val_y_mae_metric: 0.0621 - val_cotBeta_mae_metric: 0.0409
# Epoch 73/1000
# 71/71 [==============================] - ETA: 0s - loss: 101.0525 - slim_rmse_metric: 0.0799 - x_mae_metric: 0.0624 - y_mae_metric: 0.0618 - cotBeta_mae_metric: 0.0404
# Epoch 73: val_loss did not improve from 100.74181
# 71/71 [==============================] - 6s 82ms/step - loss: 101.0525 - slim_rmse_metric: 0.0799 - x_mae_metric: 0.0624 - y_mae_metric: 0.0618 - cotBeta_mae_metric: 0.0404 - val_loss: 101.0599 - val_slim_rmse_metric: 0.0811 - val_x_mae_metric: 0.0630 - val_y_mae_metric: 0.0623 - val_cotBeta_mae_metric: 0.0409
# Epoch 74/1000
# ...
# Epoch 961: val_loss improved from 71.87269 to 71.85580, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.961-t71.63-v71.86.hdf5
# 71/71 [==============================] - 6s 83ms/step - loss: 71.6300 - slim_rmse_metric: 0.0667 - x_mae_metric: 0.0561 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245 - val_loss: 71.8558 - val_slim_rmse_metric: 0.0678 - val_x_mae_metric: 0.0555 - val_y_mae_metric: 0.0541 - val_cotBeta_mae_metric: 0.0248
# Epoch 962/1000
# 71/71 [==============================] - ETA: 0s - loss: 71.6125 - slim_rmse_metric: 0.0667 - x_mae_metric: 0.0561 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245
# Epoch 962: val_loss improved from 71.85580 to 71.83907, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.962-t71.61-v71.84.hdf5
# 71/71 [==============================] - 6s 82ms/step - loss: 71.6125 - slim_rmse_metric: 0.0667 - x_mae_metric: 0.0561 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245 - val_loss: 71.8391 - val_slim_rmse_metric: 0.0678 - val_x_mae_metric: 0.0555 - val_y_mae_metric: 0.0541 - val_cotBeta_mae_metric: 0.0248
# Epoch 963/1000
# 71/71 [==============================] - ETA: 0s - loss: 71.5951 - slim_rmse_metric: 0.0667 - x_mae_metric: 0.0561 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245
# Epoch 963: val_loss improved from 71.83907 to 71.82226, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.963-t71.60-v71.82.hdf5
# 71/71 [==============================] - 6s 83ms/step - loss: 71.5951 - slim_rmse_metric: 0.0667 - x_mae_metric: 0.0561 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245 - val_loss: 71.8223 - val_slim_rmse_metric: 0.0678 - val_x_mae_metric: 0.0555 - val_y_mae_metric: 0.0541 - val_cotBeta_mae_metric: 0.0248
# Epoch 964/1000
# 71/71 [==============================] - ETA: 0s - loss: 71.5775 - slim_rmse_metric: 0.0667 - x_mae_metric: 0.0561 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245
# Epoch 964: val_loss improved from 71.82226 to 71.80551, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.964-t71.58-v71.81.hdf5
# 71/71 [==============================] - 6s 81ms/step - loss: 71.5775 - slim_rmse_metric: 0.0667 - x_mae_metric: 0.0561 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245 - val_loss: 71.8055 - val_slim_rmse_metric: 0.0678 - val_x_mae_metric: 0.0555 - val_y_mae_metric: 0.0541 - val_cotBeta_mae_metric: 0.0248
# Epoch 965/1000
# 71/71 [==============================] - ETA: 0s - loss: 71.5601 - slim_rmse_metric: 0.0666 - x_mae_metric: 0.0560 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245
# Epoch 965: val_loss improved from 71.80551 to 71.78895, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.965-t71.56-v71.79.hdf5
# 71/71 [==============================] - 6s 81ms/step - loss: 71.5601 - slim_rmse_metric: 0.0666 - x_mae_metric: 0.0560 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245 - val_loss: 71.7889 - val_slim_rmse_metric: 0.0678 - val_x_mae_metric: 0.0555 - val_y_mae_metric: 0.0541 - val_cotBeta_mae_metric: 0.0248
# Epoch 966/1000
# 71/71 [==============================] - ETA: 0s - loss: 71.5427 - slim_rmse_metric: 0.0666 - x_mae_metric: 0.0560 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245
# Epoch 966: val_loss improved from 71.78895 to 71.77232, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.966-t71.54-v71.77.hdf5
# 71/71 [==============================] - 6s 81ms/step - loss: 71.5427 - slim_rmse_metric: 0.0666 - x_mae_metric: 0.0560 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245 - val_loss: 71.7723 - val_slim_rmse_metric: 0.0678 - val_x_mae_metric: 0.0555 - val_y_mae_metric: 0.0541 - val_cotBeta_mae_metric: 0.0248
# Epoch 967/1000
# 71/71 [==============================] - ETA: 0s - loss: 71.5252 - slim_rmse_metric: 0.0666 - x_mae_metric: 0.0560 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245
# Epoch 967: val_loss improved from 71.77232 to 71.75570, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.967-t71.53-v71.76.hdf5
# 71/71 [==============================] - 6s 80ms/step - loss: 71.5252 - slim_rmse_metric: 0.0666 - x_mae_metric: 0.0560 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245 - val_loss: 71.7557 - val_slim_rmse_metric: 0.0678 - val_x_mae_metric: 0.0555 - val_y_mae_metric: 0.0541 - val_cotBeta_mae_metric: 0.0248
# Epoch 968/1000
# 71/71 [==============================] - ETA: 0s - loss: 71.5080 - slim_rmse_metric: 0.0666 - x_mae_metric: 0.0560 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245
# Epoch 968: val_loss improved from 71.75570 to 71.73910, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.968-t71.51-v71.74.hdf5
# 71/71 [==============================] - 6s 82ms/step - loss: 71.5080 - slim_rmse_metric: 0.0666 - x_mae_metric: 0.0560 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245 - val_loss: 71.7391 - val_slim_rmse_metric: 0.0678 - val_x_mae_metric: 0.0555 - val_y_mae_metric: 0.0541 - val_cotBeta_mae_metric: 0.0248
# Epoch 969/1000
# 71/71 [==============================] - ETA: 0s - loss: 71.4906 - slim_rmse_metric: 0.0666 - x_mae_metric: 0.0560 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245
# Epoch 969: val_loss improved from 71.73910 to 71.72256, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.969-t71.49-v71.72.hdf5
# 71/71 [==============================] - 6s 81ms/step - loss: 71.4906 - slim_rmse_metric: 0.0666 - x_mae_metric: 0.0560 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245 - val_loss: 71.7226 - val_slim_rmse_metric: 0.0677 - val_x_mae_metric: 0.0555 - val_y_mae_metric: 0.0541 - val_cotBeta_mae_metric: 0.0248
# Epoch 970/1000
# 71/71 [==============================] - ETA: 0s - loss: 71.4733 - slim_rmse_metric: 0.0666 - x_mae_metric: 0.0560 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245
# Epoch 970: val_loss improved from 71.72256 to 71.70608, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.970-t71.47-v71.71.hdf5
# 71/71 [==============================] - 6s 82ms/step - loss: 71.4733 - slim_rmse_metric: 0.0666 - x_mae_metric: 0.0560 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245 - val_loss: 71.7061 - val_slim_rmse_metric: 0.0677 - val_x_mae_metric: 0.0554 - val_y_mae_metric: 0.0541 - val_cotBeta_mae_metric: 0.0248
# Epoch 971/1000
# 71/71 [==============================] - ETA: 0s - loss: 71.4560 - slim_rmse_metric: 0.0666 - x_mae_metric: 0.0560 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245
# Epoch 971: val_loss improved from 71.70608 to 71.68960, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.971-t71.46-v71.69.hdf5
# 71/71 [==============================] - 6s 83ms/step - loss: 71.4560 - slim_rmse_metric: 0.0666 - x_mae_metric: 0.0560 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245 - val_loss: 71.6896 - val_slim_rmse_metric: 0.0677 - val_x_mae_metric: 0.0554 - val_y_mae_metric: 0.0541 - val_cotBeta_mae_metric: 0.0248
# Epoch 972/1000
# 71/71 [==============================] - ETA: 0s - loss: 71.4387 - slim_rmse_metric: 0.0666 - x_mae_metric: 0.0560 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245
# Epoch 972: val_loss improved from 71.68960 to 71.67326, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.972-t71.44-v71.67.hdf5
# 71/71 [==============================] - 6s 82ms/step - loss: 71.4387 - slim_rmse_metric: 0.0666 - x_mae_metric: 0.0560 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245 - val_loss: 71.6733 - val_slim_rmse_metric: 0.0677 - val_x_mae_metric: 0.0554 - val_y_mae_metric: 0.0541 - val_cotBeta_mae_metric: 0.0247
# Epoch 973/1000
# 71/71 [==============================] - ETA: 0s - loss: 71.4215 - slim_rmse_metric: 0.0666 - x_mae_metric: 0.0560 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245
# Epoch 973: val_loss improved from 71.67326 to 71.65701, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.973-t71.42-v71.66.hdf5
# 71/71 [==============================] - 6s 80ms/step - loss: 71.4215 - slim_rmse_metric: 0.0666 - x_mae_metric: 0.0560 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245 - val_loss: 71.6570 - val_slim_rmse_metric: 0.0677 - val_x_mae_metric: 0.0554 - val_y_mae_metric: 0.0541 - val_cotBeta_mae_metric: 0.0247
# Epoch 974/1000
# 71/71 [==============================] - ETA: 0s - loss: 71.4042 - slim_rmse_metric: 0.0666 - x_mae_metric: 0.0559 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245
# Epoch 974: val_loss improved from 71.65701 to 71.64069, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.974-t71.40-v71.64.hdf5
# 71/71 [==============================] - 6s 82ms/step - loss: 71.4042 - slim_rmse_metric: 0.0666 - x_mae_metric: 0.0559 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245 - val_loss: 71.6407 - val_slim_rmse_metric: 0.0677 - val_x_mae_metric: 0.0554 - val_y_mae_metric: 0.0541 - val_cotBeta_mae_metric: 0.0247
# Epoch 975/1000
# 71/71 [==============================] - ETA: 0s - loss: 71.3871 - slim_rmse_metric: 0.0666 - x_mae_metric: 0.0559 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245
# Epoch 975: val_loss improved from 71.64069 to 71.62442, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.975-t71.39-v71.62.hdf5
# 71/71 [==============================] - 6s 82ms/step - loss: 71.3871 - slim_rmse_metric: 0.0666 - x_mae_metric: 0.0559 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245 - val_loss: 71.6244 - val_slim_rmse_metric: 0.0677 - val_x_mae_metric: 0.0554 - val_y_mae_metric: 0.0541 - val_cotBeta_mae_metric: 0.0247
# Epoch 976/1000
# 71/71 [==============================] - ETA: 0s - loss: 71.3698 - slim_rmse_metric: 0.0665 - x_mae_metric: 0.0559 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245
# Epoch 976: val_loss improved from 71.62442 to 71.60815, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.976-t71.37-v71.61.hdf5
# 71/71 [==============================] - 6s 81ms/step - loss: 71.3698 - slim_rmse_metric: 0.0665 - x_mae_metric: 0.0559 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245 - val_loss: 71.6082 - val_slim_rmse_metric: 0.0677 - val_x_mae_metric: 0.0554 - val_y_mae_metric: 0.0541 - val_cotBeta_mae_metric: 0.0247
# Epoch 977/1000
# 71/71 [==============================] - ETA: 0s - loss: 71.3526 - slim_rmse_metric: 0.0665 - x_mae_metric: 0.0559 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245
# Epoch 977: val_loss improved from 71.60815 to 71.59203, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.977-t71.35-v71.59.hdf5
# 71/71 [==============================] - 6s 83ms/step - loss: 71.3526 - slim_rmse_metric: 0.0665 - x_mae_metric: 0.0559 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245 - val_loss: 71.5920 - val_slim_rmse_metric: 0.0677 - val_x_mae_metric: 0.0554 - val_y_mae_metric: 0.0541 - val_cotBeta_mae_metric: 0.0247
# Epoch 978/1000
# 71/71 [==============================] - ETA: 0s - loss: 71.3355 - slim_rmse_metric: 0.0665 - x_mae_metric: 0.0559 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245
# Epoch 978: val_loss improved from 71.59203 to 71.57607, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.978-t71.34-v71.58.hdf5
# 71/71 [==============================] - 6s 81ms/step - loss: 71.3355 - slim_rmse_metric: 0.0665 - x_mae_metric: 0.0559 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245 - val_loss: 71.5761 - val_slim_rmse_metric: 0.0677 - val_x_mae_metric: 0.0554 - val_y_mae_metric: 0.0541 - val_cotBeta_mae_metric: 0.0247
# Epoch 979/1000
# 71/71 [==============================] - ETA: 0s - loss: 71.3184 - slim_rmse_metric: 0.0665 - x_mae_metric: 0.0559 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245
# Epoch 979: val_loss improved from 71.57607 to 71.55984, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.979-t71.32-v71.56.hdf5
# 71/71 [==============================] - 6s 83ms/step - loss: 71.3184 - slim_rmse_metric: 0.0665 - x_mae_metric: 0.0559 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245 - val_loss: 71.5598 - val_slim_rmse_metric: 0.0677 - val_x_mae_metric: 0.0553 - val_y_mae_metric: 0.0541 - val_cotBeta_mae_metric: 0.0247
# Epoch 980/1000
# 71/71 [==============================] - ETA: 0s - loss: 71.3013 - slim_rmse_metric: 0.0665 - x_mae_metric: 0.0559 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245
# Epoch 980: val_loss improved from 71.55984 to 71.54385, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.980-t71.30-v71.54.hdf5
# 71/71 [==============================] - 6s 85ms/step - loss: 71.3013 - slim_rmse_metric: 0.0665 - x_mae_metric: 0.0559 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245 - val_loss: 71.5439 - val_slim_rmse_metric: 0.0677 - val_x_mae_metric: 0.0553 - val_y_mae_metric: 0.0541 - val_cotBeta_mae_metric: 0.0247
# Epoch 981/1000
# 71/71 [==============================] - ETA: 0s - loss: 71.2842 - slim_rmse_metric: 0.0665 - x_mae_metric: 0.0559 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245
# Epoch 981: val_loss improved from 71.54385 to 71.52768, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.981-t71.28-v71.53.hdf5
# 71/71 [==============================] - 6s 83ms/step - loss: 71.2842 - slim_rmse_metric: 0.0665 - x_mae_metric: 0.0559 - y_mae_metric: 0.0532 - cotBeta_mae_metric: 0.0245 - val_loss: 71.5277 - val_slim_rmse_metric: 0.0676 - val_x_mae_metric: 0.0553 - val_y_mae_metric: 0.0540 - val_cotBeta_mae_metric: 0.0247
# Epoch 982/1000
# 71/71 [==============================] - ETA: 0s - loss: 71.2671 - slim_rmse_metric: 0.0665 - x_mae_metric: 0.0559 - y_mae_metric: 0.0531 - cotBeta_mae_metric: 0.0245
# Epoch 982: val_loss improved from 71.52768 to 71.51152, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.982-t71.27-v71.51.hdf5
# 71/71 [==============================] - 6s 85ms/step - loss: 71.2671 - slim_rmse_metric: 0.0665 - x_mae_metric: 0.0559 - y_mae_metric: 0.0531 - cotBeta_mae_metric: 0.0245 - val_loss: 71.5115 - val_slim_rmse_metric: 0.0676 - val_x_mae_metric: 0.0553 - val_y_mae_metric: 0.0540 - val_cotBeta_mae_metric: 0.0247
# Epoch 983/1000
# 71/71 [==============================] - ETA: 0s - loss: 71.2500 - slim_rmse_metric: 0.0665 - x_mae_metric: 0.0559 - y_mae_metric: 0.0531 - cotBeta_mae_metric: 0.0245
# Epoch 983: val_loss improved from 71.51152 to 71.49544, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.983-t71.25-v71.50.hdf5
# 71/71 [==============================] - 6s 84ms/step - loss: 71.2500 - slim_rmse_metric: 0.0665 - x_mae_metric: 0.0559 - y_mae_metric: 0.0531 - cotBeta_mae_metric: 0.0245 - val_loss: 71.4954 - val_slim_rmse_metric: 0.0676 - val_x_mae_metric: 0.0553 - val_y_mae_metric: 0.0540 - val_cotBeta_mae_metric: 0.0247
# Epoch 984/1000
# 71/71 [==============================] - ETA: 0s - loss: 71.2330 - slim_rmse_metric: 0.0665 - x_mae_metric: 0.0558 - y_mae_metric: 0.0531 - cotBeta_mae_metric: 0.0245
# Epoch 984: val_loss improved from 71.49544 to 71.47955, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.984-t71.23-v71.48.hdf5
# 71/71 [==============================] - 6s 86ms/step - loss: 71.2330 - slim_rmse_metric: 0.0665 - x_mae_metric: 0.0558 - y_mae_metric: 0.0531 - cotBeta_mae_metric: 0.0245 - val_loss: 71.4796 - val_slim_rmse_metric: 0.0676 - val_x_mae_metric: 0.0553 - val_y_mae_metric: 0.0540 - val_cotBeta_mae_metric: 0.0247
# Epoch 985/1000
# 71/71 [==============================] - ETA: 0s - loss: 71.2160 - slim_rmse_metric: 0.0665 - x_mae_metric: 0.0558 - y_mae_metric: 0.0531 - cotBeta_mae_metric: 0.0245
# Epoch 985: val_loss improved from 71.47955 to 71.46375, saving model to ./trained_models/model-38cfae2b-checkpoints/weights.985-t71.22-v71.46.hdf5
# 71/71 [==============================] - 6s 85ms/step - loss: 71.2160 - slim_rmse_metric: 0.0665 - x_mae_metric: 0.0558 - y_mae_metric: 0.0531 - cotBeta_mae_metric: 0.0245 - val_loss: 71.4637 - val_slim_rmse_metric: 0.0676 - val_x_mae_metric: 0.0553 - val_y_mae_metric: 0.0540 - val_cotBeta_mae_metric: 0.0247
# Epoch 986/1000
# 17/71 [======>.......................] - ETA: 3s - loss: 71.4337 - slim_rmse_metric: 0.0665 - x_mae_metric: 0.0558 - y_mae_metric: 0.0539 - cotBeta_mae_metric: 0.0244

# %%
fingerprint

# %%
1
