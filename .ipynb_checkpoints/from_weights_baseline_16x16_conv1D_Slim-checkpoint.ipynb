# %%
import os
import tensorflow as tf
from tqdm import tqdm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.models import load_model
from tensorflow.keras import layers, models
from loss_functions.loss_nll import custom_loss

import OptimizedDataGenerator_v2 as DG
#from loss_functions.loss_hybrid3 import * # this one matters
#from loss_functions.loss_nll import *
from loss_functions.Slim_SSE import *
#from models.models import *
from models.Slim1D_model_Compression import *
import utils
pi = 3.14159265359

maxval=1e9
minval=1e-9
# Out:
# 2025-09-24 22:03:15.747499: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-09-24 22:03:15.747570: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-09-24 22:03:15.748696: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-09-24 22:03:15.756080: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-09-24 22:03:32.845503: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2025-09-24 22:06:27.554723: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3234 MB memory:  -> device: 0, name: NVIDIA A100-PCIE-40GB MIG 1g.5gb, pci bus id: 0000:81:00.0, compute capability: 8.0

# %%
fingerprint = '93677f46'
# c9ce48b7
TimeSlice = 20
input_shape = (16, 16, TimeSlice)
model = CreateSlim1DModel(
    input_shape=input_shape,
    
    # ========== MODEL SIZE PARAMETERS ==========
    conv_filters=5,           # Conv1D filters (5 original)
    conv_kernel_size=3,       # Conv1D kernel size (3 original)
    dense1_units=16,          # First dense layer size (16 original)
    dense2_units=16,          # Second dense layer size (16 original)
    output_units=3,           # Output size (keep at 3 for x,y,β)
    
    # ========== QUANTIZATION PARAMETERS ==========
    use_quantization=False,   # True/False to enable QKeras
    conv_weight_bits=4,       # Conv1D weight precision (4 like baseline)
    conv_activation_bits=4,   # Conv1D activation precision (4 like baseline)
    dense_weight_bits=8,      # Dense weight precision (8 like baseline)
    dense_activation_bits=8,  # Dense activation precision (8 like baseline)
    
    # ========== PRUNING PARAMETERS ==========
    use_pruning=False,        # True/False to enable pruning
    pruning_fraction=0.3,     # 0.2=20%, 0.5=50%, 0.8=80% weights removed
    pruning_schedule='constant'  # 'constant' or 'polynomial_decay'
)
'''
model = CreateSlim1DModel(
    input_shape=(16, 16, 2))
'''
base_dir = f'./trained_models/model-{fingerprint}-checkpoints/'
checkpoint_files = [os.path.join(base_dir, f) for f in os.listdir(base_dir) if f.endswith('.hdf5')]
latest_checkpoint = max(checkpoint_files, key=os.path.getmtime)
training_cp_path = os.path.join(base_dir, 'training_log.csv')
training_history = pd.read_csv(training_cp_path)

print(f"Loading model from {latest_checkpoint}")
model.load_weights(latest_checkpoint)
# Out:
# Loading model from ./trained_models/model-93677f46-checkpoints/weights.990-t40.91-v39.95.hdf5

# %%
plt.scatter(training_history['epoch'], training_history['loss'])
plt.scatter(training_history['epoch'], training_history['val_loss'])
plt.legend(['training', 'validation'])
plt.grid(True)
plt.xlabel('Epochs')
plt.ylabel('NLL loss')
plt.tight_layout() 

#plt.savefig(os.path.join(base_dir,'training_hist.png'))
plt.show()

# %%
print(training_history.to_string())
# Out:
#      epoch  cotBeta_mae_metric         loss  slim_rmse_metric  val_cotBeta_mae_metric    val_loss  val_slim_rmse_metric  val_x_mae_metric  val_y_mae_metric  x_mae_metric  y_mae_metric
# 0        0            0.207795  2068.866455          0.348819                0.098185  525.937988              0.190574          0.143344          0.180035      0.298298      0.339550
# 1        1            0.080786   432.343048          0.168846                0.068685  343.477203              0.153787          0.122261          0.134855      0.129952      0.154575
# 2        2            0.063186   296.188904          0.139479                0.059876  241.026794              0.128475          0.106401          0.101312      0.113856      0.117231
# 3        3            0.058745   221.881378          0.120529                0.057344  197.729294              0.116083          0.094453          0.088590      0.099614      0.093675
# 4        4            0.055876   190.754654          0.111593                0.054404  176.942459              0.109648          0.087963          0.083073      0.090766      0.085592
# 5        5            0.053093   173.520294          0.106304                0.051758  163.621857              0.105322          0.083873          0.079514      0.085687      0.081126
# 6        6            0.050621   161.656540          0.102500                0.049437  153.811493              0.102018          0.080887          0.077058      0.082212      0.078158
# 7        7            0.048514   152.611771          0.099499                0.047474  146.045517              0.099322          0.078541          0.075174      0.079571      0.076019
# 8        8            0.046753   145.302444          0.097005                0.045828  139.595062              0.097024          0.076597          0.073632      0.077455      0.074321
# 9        9            0.045262   139.130829          0.094848                0.044431  134.027039              0.094992          0.074936          0.072311      0.075681      0.072888
# 10      10            0.043978   133.735947          0.092920                0.043224  129.070831              0.093142          0.073459          0.071140      0.074129      0.071634
# 11      11            0.042856   128.896881          0.091156                0.042162  124.558403              0.091423          0.072112          0.070089      0.072723      0.070512
# 12      12            0.041858   124.477325          0.089514                0.041204  120.388039              0.089801          0.070871          0.069121      0.071429      0.069486
# 13      13            0.040949   120.394005          0.087969                0.040314  116.494049              0.088258          0.069720          0.068211      0.070236      0.068533
# 14      14            0.040108   116.588120          0.086504                0.039478  112.841896              0.086783          0.068665          0.067347      0.069136      0.067628
# 15      15            0.039315   113.008926          0.085102                0.038698  109.436905              0.085382          0.067751          0.066517      0.068129      0.066749
# 16      16            0.038556   109.610504          0.083749                0.037977  106.221390              0.084039          0.066954          0.065690      0.067194      0.065888
# 17      17            0.037837   106.379356          0.082442                0.037297  103.122513              0.082726          0.066170          0.064853      0.066303      0.065046
# 18      18            0.037163   103.355255          0.081199                0.036654  100.235504              0.081485          0.065428          0.064049      0.065452      0.064237
# 19      19            0.036534   100.581161          0.080042                0.036050   97.584618              0.080332          0.064687          0.063303      0.064635      0.063489
# 20      20            0.035952    98.065926          0.078978                0.035487   95.176025              0.079273          0.063930          0.062631      0.063836      0.062813
# 21      21            0.035415    95.794289          0.078005                0.034967   92.998207              0.078304          0.063159          0.062033      0.063050      0.062209
# 22      22            0.034919    93.740715          0.077115                0.034485   91.030014              0.077419          0.062397          0.061496      0.062277      0.061666
# 23      23            0.034459    91.875252          0.076298                0.034036   89.239769              0.076607          0.061647          0.061010      0.061521      0.061174
# 24      24            0.034028    90.168320          0.075542                0.033613   87.606148              0.075860          0.060931          0.060555      0.060787      0.060721
# 25      25            0.033619    88.598251          0.074840                0.033209   86.103539              0.075166          0.060251          0.060124      0.060085      0.060296
# 26      26            0.033227    87.145149          0.074184                0.032821   84.723022              0.074524          0.059619          0.059712      0.059422      0.059892
# 27      27            0.032848    85.795975          0.073570                0.032443   83.445137              0.073924          0.059035          0.059317      0.058801      0.059503
# 28      28            0.032478    84.540497          0.072993                0.032073   82.262093              0.073366          0.058502          0.058935      0.058224      0.059128
# 29      29            0.032117    83.369431          0.072451                0.031711   81.166138              0.072844          0.058021          0.058566      0.057692      0.058765
# 30      30            0.031761    82.276573          0.071942                0.031359   80.145912              0.072356          0.057589          0.058209      0.057206      0.058412
# 31      31            0.031413    81.253510          0.071461                0.031012   79.203293              0.071903          0.057210          0.057865      0.056764      0.058068
# 32      32            0.031072    80.301208          0.071011                0.030673   78.322792              0.071475          0.056871          0.057531      0.056369      0.057735
# 33      33            0.030738    79.400017          0.070581                0.030341   77.512337              0.071080          0.056584          0.057208      0.056000      0.057410
# 34      34            0.030413    78.580437          0.070188                0.030017   76.722061              0.070693          0.056291          0.056894      0.055697      0.057098
# 35      35            0.030094    77.721512          0.069775                0.029699   76.050941              0.070362          0.056113          0.056596      0.055321      0.056789
# 36      36            0.029793    77.195000          0.069517                0.029392   75.088181              0.069884          0.055533          0.056296      0.055306      0.056518
# 37      37            0.029479    76.012291          0.068945                0.029091   74.199722              0.069438          0.054799          0.056160      0.054509      0.056172
# 38      38            0.029251    75.959846          0.068914                0.028864   73.623375              0.069142          0.054259          0.056212      0.054882      0.056078
# 39      39            0.028914    74.817444          0.068356                0.028554   72.865456              0.068764          0.054033          0.055800      0.054257      0.055582
# 40      40            0.028672    74.538757          0.068216                0.028335   72.510727              0.068582          0.053822          0.055830      0.054389      0.055418
# 41      41            0.028408    73.760551          0.067832                0.028082   71.994324              0.068322          0.053651          0.055631      0.053986      0.055134
# 42      42            0.028154    73.324959          0.067614                0.027841   71.486000              0.068064          0.053484          0.055430      0.053992      0.054874
# 43      43            0.027916    72.705933          0.067305                0.027651   71.225800              0.067932          0.053339          0.055503      0.053713      0.054647
# 44      44            0.027684    72.243347          0.067073                0.027405   70.657799              0.067642          0.053203          0.055183      0.053644      0.054404
# 45      45            0.027425    71.615036          0.066757                0.027091   69.641884              0.067117          0.053065          0.054311      0.053468      0.054046
# 46      46            0.027277    71.554695          0.066722                0.026885   68.821190              0.066692          0.052937          0.053718      0.053431      0.054279
# 47      47            0.027038    70.592850          0.066239                0.026691   68.906151              0.066734          0.052942          0.053968      0.052951      0.053722
# 48      48            0.026868    70.649811          0.066264                0.026473   68.265717              0.066403          0.052692          0.053609      0.053386      0.053612
# 49      49            0.026633    69.720398          0.065794                0.026327   68.121437              0.066330          0.052581          0.053737      0.052775      0.053249
# 50      50            0.026494    69.764557          0.065814                0.026175   67.869995              0.066199          0.052476          0.053720      0.053060      0.053262
# 51      51            0.026262    68.932449          0.065390                0.025963   67.309029              0.065906          0.052373          0.053306      0.052607      0.052843
# 52      52            0.026076    68.793030          0.065316                0.025820   67.082657              0.065786          0.052285          0.053293      0.052859      0.052630
# 53      53            0.026073    68.816040          0.065325                0.025566   66.322372              0.065387          0.052325          0.052474      0.052551      0.053168
# 54      54            0.025743    67.779594          0.064793                0.025406   65.864441              0.065139          0.052229          0.052186      0.052302      0.052235
# 55      55            0.025615    67.834526          0.064818                0.025259   65.544212              0.064972          0.052003          0.052124      0.052615      0.052187
# 56      56            0.025490    67.316040          0.064552                0.025352   66.509918              0.065486          0.052147          0.053427      0.052156      0.052150
# 57      57            0.025369    67.314308          0.064549                0.025005   65.144684              0.064762          0.051864          0.052048      0.052438      0.052047
# 58      58            0.025151    66.529526          0.064141                0.024833   64.523880              0.064426          0.051800          0.051523      0.051976      0.051644
# 59      59            0.025092    66.679123          0.064214                0.024690   64.261795              0.064288          0.051679          0.051413      0.052130      0.051844
# 60      60            0.024968    66.439545          0.064091                0.024644   64.665619              0.064504          0.051929          0.051848      0.052112      0.051709
# 61      61            0.024773    65.793373          0.063754                0.024460   63.888863              0.064089          0.051541          0.051319      0.051873      0.051231
# 62      62            0.024643    65.574638          0.063638                0.024373   63.863266              0.064075          0.051568          0.051407      0.051831      0.051139
# 63      63            0.024659    65.855446          0.063783                0.024284   63.627174              0.063949          0.051391          0.051376      0.051952      0.051534
# 64      64            0.024400    64.882202          0.063273                0.024091   63.039612              0.063631          0.051321          0.050825      0.051496      0.050821
# 65      65            0.024316    65.046967          0.063358                0.024008   62.948681              0.063582          0.051283          0.050858      0.051820      0.050852
# 66      66            0.024300    64.928757          0.063296                0.024185   63.850517              0.064074          0.051358          0.052130      0.051563      0.051078
# 67      67            0.024090    64.398361          0.063015                0.023778   62.392250              0.063281          0.051150          0.050491      0.051530      0.050527
# 68      68            0.023992    64.230553          0.062924                0.023674   62.073364              0.063104          0.051077          0.050295      0.051448      0.050505
# 69      69            0.023928    64.040604          0.062822                0.023574   61.890926              0.063005          0.051005          0.050207      0.051293      0.050510
# 70      70            0.023880    64.353828          0.062986                0.023542   62.074512              0.063105          0.051091          0.050457      0.051725      0.050621
# 71      71            0.023694    63.399670          0.062480                0.023400   61.594849              0.062845          0.050948          0.050055      0.051095      0.050059
# 72      72            0.023620    63.367035          0.062461                0.023307   61.373928              0.062719          0.050957          0.049897      0.051112      0.050110
# 73      73            0.023650    63.736176          0.062657                0.023435   62.328686              0.063248          0.051261          0.050986      0.051421      0.050387
# 74      74            0.023459    63.044277          0.062287                0.023141   61.012951              0.062524          0.050757          0.049757      0.051119      0.049856
# 75      75            0.023350    62.704350          0.062103                0.023055   60.781204              0.062393          0.050699          0.049622      0.050865      0.049747
# 76      76            0.023360    63.063934          0.062294                0.023154   61.638737              0.062869          0.051037          0.050552      0.051222      0.049958
# 77      77            0.023279    62.790024          0.062147                0.022903   60.506172              0.062242          0.050595          0.049497      0.051079      0.049823
# 78      78            0.023109    62.157890          0.061806                0.022822   60.294865              0.062124          0.050561          0.049356      0.050681      0.049453
# 79      79            0.023104    62.497910          0.061987                0.022788   60.542767              0.062261          0.050753          0.049588      0.051044      0.049631
# 80      80            0.023042    62.275963          0.061867                0.022698   60.098602              0.062014          0.050436          0.049340      0.050914      0.049542
# 81      81            0.022889    61.712654          0.061562                0.022604   59.848175              0.061874          0.050388          0.049140      0.050595      0.049173
# 82      82            0.022873    61.867634          0.061643                0.022549   59.825821              0.061861          0.050411          0.049169      0.050752      0.049303
# 83      83            0.022900    62.274956          0.061860                0.022471   59.575195              0.061719          0.050301          0.048997      0.051038      0.049656
# 84      84            0.022690    61.262096          0.061314                0.022401   59.609684              0.061743          0.050559          0.048884      0.050441      0.048941
# 85      85            0.022662    61.183338          0.061270                0.022355   59.285160              0.061558          0.050244          0.048837      0.050279      0.049077
# 86      86            0.022649    61.815685          0.061611                0.022281   59.158199              0.061486          0.050174          0.048769      0.051155      0.049117
# 87      87            0.022507    60.890671          0.061109                0.022245   59.377766              0.061614          0.050591          0.048782      0.050343      0.048753
# 88      88            0.022534    61.500877          0.061437                0.022160   59.224880              0.061528          0.050578          0.048595      0.050882      0.049138
# 89      89            0.022394    60.581589          0.060939                0.022101   58.901443              0.061345          0.050273          0.048526      0.050161      0.048642
# 90      90            0.022373    60.577751          0.060936                0.022067   58.774670              0.061273          0.050200          0.048509      0.050120      0.048746
# 91      91            0.022342    60.956436          0.061141                0.021995   58.614578              0.061179          0.050060          0.048467      0.050747      0.048690
# 92      92            0.022225    60.245811          0.060753                0.021938   58.525948              0.061133          0.050143          0.048329      0.050161      0.048362
# 93      93            0.022284    61.063278          0.061196                0.021884   58.424202              0.061074          0.050109          0.048257      0.050797      0.048951
# 94      94            0.022121    59.952526          0.060591                0.021830   58.272602              0.060989          0.050038          0.048191      0.049970      0.048276
# 95      95            0.022100    59.967598          0.060598                0.021808   58.338840              0.061028          0.050210          0.048199      0.049961      0.048374
# 96      96            0.022085    60.173492          0.060711                0.021732   58.875092              0.061325          0.051073          0.048211      0.050270      0.048397
# 97      97            0.022020    60.099850          0.060670                0.021677   57.854519              0.060750          0.049791          0.048019      0.050457      0.048143
# 98      98            0.021971    60.023499          0.060625                0.021730   58.483479              0.061111          0.050564          0.048259      0.050232      0.048389
# 99      99            0.021913    59.566376          0.060376                0.021580   58.024826              0.060852          0.050295          0.047874      0.049880      0.048130
# 100    100            0.021846    59.334812          0.060247                0.021567   57.729092              0.060681          0.049953          0.047872      0.049728      0.048018
# 101    101            0.021851    60.035217          0.060630                0.021491   57.410961              0.060495          0.049642          0.047765      0.050664      0.048089
# 102    102            0.021744    59.201077          0.060172                0.021507   57.777130              0.060709          0.050161          0.047856      0.049847      0.047824
# 103    103            0.021774    59.607414          0.060394                0.021409   57.999088              0.060839          0.050714          0.047648      0.050203      0.048096
# 104    104            0.021660    58.995472          0.060058                0.021368   57.559826              0.060587          0.050196          0.047585      0.049763      0.047730
# 105    105            0.021651    58.920521          0.060016                0.021353   57.442005              0.060519          0.050100          0.047575      0.049620      0.047820
# 106    106            0.021626    59.446476          0.060303                0.021282   56.989540              0.060253          0.049585          0.047480      0.050462      0.047737
# 107    107            0.021533    58.708534          0.059897                0.021349   57.363831              0.060473          0.050014          0.047671      0.049738      0.047500
# 108    108            0.021599    59.174744          0.060153                0.021210   57.334385              0.060458          0.050299          0.047352      0.050059      0.047890
# 109    109            0.021455    58.496655          0.059778                0.021179   57.125114              0.060338          0.050101          0.047303      0.049632      0.047411
# 110    110            0.021451    58.598026          0.059835                0.021150   57.856255              0.060762          0.051248          0.047277      0.049721      0.047522
# 111    111            0.021412    58.920891          0.060012                0.021096   56.847343              0.060177          0.049847          0.047218      0.050328      0.047404
# 112    112            0.021348    58.167919          0.059593                0.021113   56.583797              0.060023          0.049584          0.047178      0.049451      0.047276
# 113    113            0.021398    58.317074          0.059676                0.021050   56.469997              0.059958          0.049566          0.047071      0.049483      0.047485
# 114    114            0.021307    58.439774          0.059743                0.020993   56.277557              0.059842          0.049379          0.047019      0.049990      0.047184
# 115    115            0.021249    57.992455          0.059495                0.021067   56.656467              0.060066          0.049843          0.047169      0.049558      0.047043
# 116    116            0.021357    58.710651          0.059893                0.020933   56.320656              0.059871          0.049638          0.046888      0.050095      0.047574
# 117    117            0.021170    57.715305          0.059338                0.020919   56.306156              0.059863          0.049706          0.046853      0.049393      0.046912
# 118    118            0.021182    57.802391          0.059387                0.020923   56.887531              0.060203          0.050579          0.046882      0.049420      0.047063
# 119    119            0.021168    58.346493          0.059690                0.020836   55.988731              0.059677          0.049421          0.046736      0.050248      0.047036
# 120    120            0.021089    57.479820          0.059205                0.020859   55.959034              0.059660          0.049455          0.046719      0.049291      0.046815
# 121    121            0.021130    57.585144          0.059263                0.020830   55.867287              0.059606          0.049418          0.046663      0.049282      0.047010
# 122    122            0.021073    57.873024          0.059423                0.020755   55.623257              0.059460          0.049186          0.046572      0.049924      0.046800
# 123    123            0.021013    57.365032          0.059140                0.020920   56.375343              0.059903          0.049986          0.046934      0.049401      0.046665
# 124    124            0.021101    57.942097          0.059462                0.020706   55.912228              0.059633          0.049775          0.046458      0.049877      0.047052
# 125    125            0.020939    57.072395          0.058974                0.020705   55.735489              0.059530          0.049595          0.046427      0.049237      0.046498
# 126    126            0.020964    57.103939          0.058992                0.020724   55.770779              0.059551          0.049667          0.046450      0.049160      0.046666
# 127    127            0.020955    57.632900          0.059287                0.020627   55.433075              0.059347          0.049342          0.046326      0.049969      0.046617
# 128    128            0.020864    56.887005          0.058869                0.020696   55.561512              0.059427          0.049481          0.046403      0.049291      0.046290
# 129    129            0.020970    57.540707          0.059235                0.020600   55.524158              0.059405          0.049629          0.046211      0.049741      0.046829
# 130    130            0.020819    56.711090          0.058769                0.020591   55.420807              0.059345          0.049553          0.046176      0.049157      0.046263
# 131    131            0.020839    56.775578          0.058806                0.020599   55.894123              0.059624          0.050269          0.046192      0.049151      0.046408
# 132    132            0.020824    57.357037          0.059132                0.020507   55.011547              0.059102          0.049131          0.046051      0.050069      0.046339
# 133    133            0.020753    56.472927          0.058633                0.020563   55.050575              0.059125          0.049217          0.046066      0.049055      0.046142
# 134    134            0.020808    56.600582          0.058704                0.020526   54.964428              0.059074          0.049195          0.045992      0.049046      0.046366
# 135    135            0.020745    56.890896          0.058867                0.020452   54.705116              0.058918          0.048957          0.045888      0.049714      0.046130
# 136    136            0.020700    56.408428          0.058596                0.020642   55.558670              0.059424          0.049847          0.046293      0.049182      0.046032
# 137    137            0.020772    56.924755          0.058886                0.020408   55.101547              0.059156          0.049665          0.045793      0.049657      0.046331
# 138    138            0.020629    56.106579          0.058424                0.020419   54.862232              0.059014          0.049376          0.045768      0.049016      0.045841
# 139    139            0.020667    56.143890          0.058444                0.020459   54.614841              0.058865          0.049016          0.045804      0.048909      0.046040
# 140    140            0.020661    56.686897          0.058751                0.020349   54.378895              0.058723          0.048861          0.045641      0.049759      0.045974
# 141    141            0.020580    56.009514          0.058367                0.020463   55.146912              0.059180          0.049800          0.045864      0.049066      0.045758
# 142    142            0.020636    56.594177          0.058697                0.020301   54.684349              0.058907          0.049428          0.045552      0.049683      0.046013
# 143    143            0.020521    55.749126          0.058218                0.020324   54.453403              0.058769          0.049145          0.045534      0.048908      0.045614
# 144    144            0.020570    55.848469          0.058274                0.020351   54.288658              0.058669          0.048917          0.045555      0.048858      0.045842
# 145    145            0.020546    56.270184          0.058513                0.020246   54.072655              0.058539          0.048778          0.045406      0.049599      0.045715
# 146    146            0.020477    55.685188          0.058181                0.020388   54.916607              0.059042          0.049774          0.045683      0.048996      0.045534
# 147    147            0.020542    56.297779          0.058528                0.020200   54.284058              0.058666          0.049199          0.045322      0.049628      0.045815
# 148    148            0.020414    55.416634          0.058026                0.020225   54.182766              0.058606          0.049102          0.045305      0.048839      0.045373
# 149    149            0.020462    55.504753          0.058076                0.020261   54.035709              0.058516          0.048881          0.045342      0.048769      0.045606
# 150    150            0.020445    55.999493          0.058357                0.020151   53.786854              0.058365          0.048702          0.045183      0.049584      0.045508
# 151    151            0.020371    55.361103          0.057993                0.020277   54.578609              0.058839          0.049659          0.045412      0.048923      0.045306
# 152    152            0.020430    55.953960          0.058330                0.020105   54.060143              0.058531          0.049208          0.045103      0.049548      0.045563
# 153    153            0.020313    55.105019          0.057845                0.020131   53.892773              0.058430          0.049010          0.045089      0.048763      0.045160
# 154    154            0.020365    55.205318          0.057902                0.020168   53.757984              0.058347          0.048804          0.045126      0.048698      0.045405
# 155    155            0.020343    55.683296          0.058174                0.020057   53.514668              0.058200          0.048630          0.044969      0.049504      0.045291
# 156    156            0.020271    55.057133          0.057816                0.020182   54.321629              0.058684          0.049616          0.045187      0.048853      0.045092
# 157    157            0.020330    55.658493          0.058159                0.020010   53.753239              0.058344          0.049079          0.044896      0.049495      0.045346
# 158    158            0.020212    54.805225          0.057670                0.020038   53.632168              0.058271          0.048947          0.044880      0.048694      0.044948
# 159    159            0.020266    54.909454          0.057729                0.020078   53.518425              0.058201          0.048762          0.044923      0.048626      0.045203
# 160    160            0.020244    55.408142          0.058014                0.019966   53.256126              0.058042          0.048560          0.044767      0.049459      0.045090
# 161    161            0.020172    54.766113          0.057646                0.020084   54.038845              0.058513          0.049534          0.044958      0.048788      0.044886
# 162    162            0.020229    55.358517          0.057985                0.019918   53.520969              0.058203          0.049043          0.044699      0.049428      0.045129
# 163    163            0.020117    54.522301          0.057504                0.019949   53.381767              0.058118          0.048883          0.044681      0.048629      0.044751
# 164    164            0.020172    54.630756          0.057566                0.019992   53.296921              0.058066          0.048735          0.044729      0.048559      0.045015
# 165    165            0.020148    55.147549          0.057862                0.019879   53.009544              0.057890          0.048493          0.044573      0.049422      0.044896
# 166    166            0.020077    54.490490          0.057485                0.019992   53.761127              0.058344          0.049437          0.044745      0.048725      0.044692
# 167    167            0.020131    55.060810          0.057811                0.019831   53.329056              0.058085          0.049050          0.044510      0.049346      0.044923
# 168    168            0.020024    54.255035          0.057347                0.019861   53.153862              0.057979          0.048838          0.044490      0.048568      0.044564
# 169    169            0.020080    54.361088          0.057408                0.019910   53.067760              0.057925          0.048681          0.044542      0.048489      0.044835
# 170    170            0.020056    54.897629          0.057716                0.019796   52.773499              0.057745          0.048427          0.044388      0.049380      0.044713
# 171    171            0.019986    54.226097          0.057329                0.019900   53.520153              0.058198          0.049384          0.044540      0.048664      0.044506
# 172    172            0.020037    54.786304          0.057651                0.019746   53.107178              0.057949          0.049000          0.044333      0.049282      0.044724
# 173    173            0.019935    53.997669          0.057195                0.019779   52.932774              0.057843          0.048789          0.044310      0.048507      0.044385
# 174    174            0.019994    54.107033          0.057258                0.019829   52.857937              0.057796          0.048646          0.044362      0.048422      0.044668
# 175    175            0.019966    54.660145          0.057577                0.019716   52.546989              0.057605          0.048361          0.044214      0.049345      0.044534
# 176    176            0.019898    53.972782          0.057180                0.019815   53.263920              0.058041          0.049293          0.044347      0.048602      0.044331
# 177    177            0.019946    54.512527          0.057490                0.019666   52.930672              0.057840          0.049002          0.044165      0.049203      0.044535
# 178    178            0.019850    53.755188          0.057052                0.019699   52.729832              0.057718          0.048753          0.044140      0.048451      0.044217
# 179    179            0.019910    53.860176          0.057112                0.019753   52.661869              0.057674          0.048617          0.044193      0.048356      0.044504
# 180    180            0.019882    54.438374          0.057446                0.019641   52.329914              0.057470          0.048297          0.044051      0.049314      0.044368
# 181    181            0.019815    53.727798          0.057034                0.019730   53.009235              0.057884          0.049194          0.044160      0.048539      0.044162
# 182    182            0.019860    54.250050          0.057335                0.019590   52.763184              0.057736          0.049007          0.044005      0.049124      0.044356
# 183    183            0.019769    53.523792          0.056914                0.019621   52.535484              0.057597          0.048719          0.043978      0.048397      0.044057
# 184    184            0.019831    53.623329          0.056971                0.019679   52.449780              0.057543          0.048555          0.044032      0.048288      0.044350
# 185    185            0.019801    54.211617          0.057312                0.019567   52.118896              0.057339          0.048235          0.043894      0.049265      0.044208
# 186    186            0.019735    53.496262          0.056896                0.019648   52.809464              0.057761          0.049161          0.043987      0.048482      0.044002
# 187    187            0.019777    54.012592          0.057195                0.019513   52.553581              0.057607          0.048939          0.043857      0.049071      0.044183
# 188    188            0.019691    53.292625          0.056776                0.019551   52.334179              0.057473          0.048664          0.043825      0.048336      0.043899
# 189    189            0.019758    53.400215          0.056838                0.019605   52.218372              0.057400          0.048461          0.043873      0.048222      0.044210
# 190    190            0.019723    53.976803          0.057173                0.019495   51.915009              0.057212          0.048174          0.043744      0.049202      0.044047
# 191    191            0.019661    53.281250          0.056768                0.019576   52.660725              0.057669          0.049185          0.043833      0.048434      0.043853
# 192    192            0.019701    53.783985          0.057060                0.019438   52.338776              0.057474          0.048851          0.043722      0.049017      0.044022
# 193    193            0.019616    53.068157          0.056642                0.019484   52.147804              0.057357          0.048619          0.043681      0.048278      0.043746
# 194    194            0.019689    53.184727          0.056710                0.019532   52.010956              0.057271          0.048394          0.043721      0.048158      0.044078
# 195    195            0.019648    53.761131          0.057045                0.019427   51.718746              0.057090          0.048115          0.043602      0.049157      0.043893
# 196    196            0.019590    53.067139          0.056641                0.019505   52.473202              0.057554          0.049143          0.043685      0.048380      0.043711
# 197    197            0.019629    53.557652          0.056926                0.019369   52.162086              0.057365          0.048811          0.043591      0.048954      0.043870
# 198    198            0.019546    52.853657          0.056514                0.019419   51.970081              0.057247          0.048579          0.043545      0.048221      0.043603
# 199    199            0.019624    52.971996          0.056583                0.019467   51.787613              0.057133          0.048291          0.043581      0.048090      0.043950
# 200    200            0.019580    53.542400          0.056916                0.019361   51.529858              0.056973          0.048057          0.043468      0.049094      0.043747
# 201    201            0.019524    52.867607          0.056521                0.019441   52.353931              0.057479          0.049188          0.043549      0.048336      0.043576
# 202    202            0.019562    53.340195          0.056797                0.019303   51.965645              0.057243          0.048729          0.043472      0.048893      0.043723
# 203    203            0.019480    52.645126          0.056389                0.019362   51.803799              0.057143          0.048546          0.043417      0.048166      0.043464
# 204    204            0.019566    52.771088          0.056463                0.019399   51.586559              0.057007          0.048219          0.043442      0.048025      0.043832
# 205    205            0.019514    53.338486          0.056794                0.019302   51.346359              0.056858          0.048000          0.043339      0.049047      0.043604
# 206    206            0.019462    52.671295          0.056404                0.019381   52.185284              0.057375          0.049155          0.043416      0.048285      0.043447
# 207    207            0.019499    53.120911          0.056666                0.019243   51.813251              0.057147          0.048708          0.043353      0.048820      0.043584
# 208    208            0.019420    52.447979          0.056271                0.019305   51.649773              0.057047          0.048524          0.043292      0.048115      0.043333
# 209    209            0.019509    52.570534          0.056342                0.019343   51.391285              0.056885          0.048139          0.043315      0.047959      0.043711
# 210    210            0.019455    53.141712          0.056677                0.019246   51.171116              0.056748          0.047944          0.043216      0.048995      0.043471
# 211    211            0.019405    52.482830          0.056290                0.019323   52.047104              0.057288          0.049160          0.043289      0.048240      0.043320
# 212    212            0.019441    52.907978          0.056539                0.019189   51.655605              0.057049          0.048668          0.043244      0.048749      0.043446
# 213    213            0.019364    52.257401          0.056156                0.019257   51.504631              0.056955          0.048507          0.043175      0.048064      0.043207
# 214    214            0.019459    52.377354          0.056226                0.019291   51.184143              0.056755          0.048034          0.043193      0.047893      0.043597
# 215    215            0.019402    52.941719          0.056557                0.019195   51.003719              0.056642          0.047892          0.043098      0.048931      0.043341
# 216    216            0.019353    52.312321          0.056187                0.019273   51.957409              0.057231          0.049223          0.043172      0.048210      0.043201
# 217    217            0.019387    52.685673          0.056406                0.019139   51.524193              0.056966          0.048659          0.043141      0.048658      0.043314
# 218    218            0.019312    52.080677          0.056049                0.019207   51.393471              0.056885          0.048534          0.043061      0.048025      0.043086
# 219    219            0.019412    52.188332          0.056112                0.019246   50.984299              0.056629          0.047928          0.043083      0.047825      0.043488
# 220    220            0.019354    52.749096          0.056442                0.019146   50.845615              0.056543          0.047846          0.042988      0.048865      0.043220
# 221    221            0.019304    52.156143          0.056092                0.019224   51.887470              0.057187          0.049313          0.043058      0.048195      0.043085
# 222    222            0.019334    52.449905          0.056265                0.019093   51.422150              0.056901          0.048691          0.043038      0.048544      0.043181
# 223    223            0.019264    51.924427          0.055954                0.019155   51.326115              0.056841          0.048625          0.042949      0.048006      0.042973
# 224    224            0.019366    52.001698          0.055999                0.019211   50.811031              0.056519          0.047846          0.042985      0.047758      0.043378
# 225    225            0.019310    52.568859          0.056333                0.019102   50.692245              0.056445          0.047801          0.042881      0.048802      0.043114
# 226    226            0.019257    51.996704          0.055995                0.019172   51.780762              0.057119          0.049348          0.042942      0.048172      0.042968
# 227    227            0.019284    52.221653          0.056128                0.019052   51.311226              0.056831          0.048708          0.042934      0.048434      0.043051
# 228    228            0.019220    51.775558          0.055863                0.019107   51.253067              0.056794          0.048702          0.042841      0.047987      0.042868
# 229    229            0.019323    51.820210          0.055888                0.019187   50.633938              0.056406          0.047742          0.042902      0.047695      0.043270
# 230    230            0.019273    52.376995          0.056216                0.019062   50.548866              0.056354          0.047765          0.042778      0.048715      0.043011
# 231    231            0.019213    51.873852          0.055919                0.019128   51.706558              0.057071          0.049424          0.042830      0.048195      0.042855
# 232    232            0.019233    51.936619          0.055957                0.019014   51.225662              0.056776          0.048777          0.042812      0.048244      0.042917
# 233    233            0.019181    51.711079          0.055822                0.019031   51.335499              0.056844          0.049013          0.042739      0.048078      0.042772
# 234    234            0.019262    51.629169          0.055772                0.019161   50.690735              0.056441          0.047973          0.042819      0.047673      0.043104
# 235    235            0.019243    52.215321          0.056119                0.019032   50.359837              0.056233          0.047659          0.042675      0.048609      0.042987
# 236    236            0.019166    51.554657          0.055727                0.019048   51.368233              0.056861          0.049145          0.042689      0.047957      0.042711
# 237    237            0.019198    51.997768          0.055989                0.018974   50.726456              0.056464          0.048158          0.042772      0.048529      0.042796
# 238    238            0.019146    51.355766          0.055607                0.019138   50.735073              0.056467          0.048158          0.042753      0.047740      0.042683
# 239    239            0.019264    51.563549          0.055729                0.019054   50.289082              0.056184          0.047669          0.042627      0.047667      0.043088
# 240    240            0.019166    51.854721          0.055902                0.018988   50.273605              0.056179          0.047698          0.042579      0.048451      0.042690
# 241    241            0.019152    51.859665          0.055902                0.019028   50.924477              0.056583          0.048637          0.042594      0.048470      0.042732
# 242    242            0.019129    51.240803          0.055536                0.018971   50.455135              0.056293          0.048029          0.042544      0.047685      0.042633
# 243    243            0.019168    51.269817          0.055553                0.019074   50.646915              0.056411          0.048229          0.042629      0.047584      0.042814
# 244    244            0.019183    52.451641          0.056244                0.018928   50.170605              0.056110          0.047570          0.042622      0.049302      0.042749
# 245    245            0.019066    50.963089          0.055367                0.018982   50.078293              0.056054          0.047560          0.042497      0.047536      0.042412
# 246    246            0.019159    51.254128          0.055541                0.019008   50.442993              0.056283          0.048086          0.042511      0.047645      0.042780
# 247    247            0.019121    51.584206          0.055737                0.018919   51.517864              0.056949          0.049731          0.042507      0.048264      0.042638
# 248    248            0.019058    51.110744          0.055456                0.018903   50.584461              0.056372          0.048385          0.042480      0.047819      0.042402
# 249    249            0.019173    51.150723          0.055478                0.019108   50.143646              0.056091          0.047583          0.042611      0.047455      0.042890
# 250    250            0.019115    51.694878          0.055801                0.018919   49.925613              0.055956          0.047514          0.042384      0.048477      0.042604
# 251    251            0.019050    51.124348          0.055461                0.018949   51.119820              0.056701          0.049277          0.042402      0.047890      0.042403
# 252    252            0.019077    51.374557          0.055610                0.018876   50.498272              0.056316          0.048318          0.042485      0.048200      0.042473
# 253    253            0.019036    50.915092          0.055334                0.019001   50.455166              0.056287          0.048275          0.042430      0.047639      0.042395
# 254    254            0.019159    51.172234          0.055487                0.018999   50.110737              0.056061          0.047866          0.042398      0.047631      0.042811
# 255    255            0.019052    51.207542          0.055507                0.018897   49.919395              0.055951          0.047648          0.042303      0.048076      0.042377
# 256    256            0.019044    51.516174          0.055689                0.018875   49.963116              0.055977          0.047736          0.042276      0.048506      0.042435
# 257    257            0.019007    50.686798          0.055194                0.018895   49.925640              0.055954          0.047711          0.042273      0.047462      0.042289
# 258    258            0.019077    50.815693          0.055271                0.018941   50.171379              0.056107          0.048042          0.042313      0.047420      0.042562
# ...
# 914    914            0.016127    41.336941          0.048744                0.015915   41.210640              0.049745          0.041315          0.038022      0.040687      0.038086
# 915    915            0.016151    41.576923          0.048903                0.015931   40.488228              0.049227          0.040043          0.038076      0.040460      0.038829
# 916    916            0.016104    41.144489          0.048612                0.015931   40.809559              0.049457          0.040303          0.038401      0.040408      0.038047
# 917    917            0.016105    41.535488          0.048877                0.015941   40.775826              0.049425          0.040680          0.037986      0.040666      0.038551
# 918    918            0.016164    41.288891          0.048711                0.016015   42.189327              0.050417          0.041193          0.040185      0.040686      0.037997
# 919    919            0.016091    41.917221          0.049131                0.015943   40.913265              0.049531          0.040921          0.037840      0.041152      0.038688
# 920    920            0.016164    41.100815          0.048577                0.015911   40.696827              0.049375          0.040305          0.038168      0.039972      0.038430
# 921    921            0.016098    41.350594          0.048747                0.015918   40.468208              0.049209          0.039961          0.038133      0.040519      0.038356
# 922    922            0.016112    41.195667          0.048643                0.015920   40.943783              0.049546          0.040403          0.038574      0.040314      0.038273
# 923    923            0.016104    41.920902          0.049131                0.015920   40.436676              0.049187          0.040094          0.037860      0.041434      0.038382
# 924    924            0.016159    41.052799          0.048542                0.015908   40.586323              0.049293          0.040146          0.038142      0.039914      0.038419
# 925    925            0.016088    41.306305          0.048715                0.015910   40.462940              0.049203          0.039950          0.038134      0.040463      0.038345
# 926    926            0.016104    41.164371          0.048619                0.015922   40.614605              0.049310          0.040013          0.038371      0.040270      0.038281
# 927    927            0.016075    41.423409          0.048794                0.015933   40.511108              0.049232          0.040268          0.037902      0.040748      0.038272
# 928    928            0.016120    41.428783          0.048799                0.016132   40.815727              0.049451          0.039934          0.038761      0.040457      0.038561
# 929    929            0.016215    41.161568          0.048616                0.016019   41.232216              0.049741          0.040127          0.039500      0.040462      0.038025
# 930    930            0.016079    41.086231          0.048564                0.015901   40.371647              0.049134          0.039907          0.038034      0.039900      0.038569
# 931    931            0.016094    41.675297          0.048958                0.015940   40.871819              0.049487          0.040147          0.038739      0.041475      0.037874
# 932    932            0.016108    41.494267          0.048841                0.015898   41.074829              0.049636          0.041239          0.037863      0.040352      0.038817
# 933    933            0.016102    41.167408          0.048616                0.015893   41.481266              0.049921          0.041909          0.037927      0.040302      0.038245
# 934    934            0.016089    41.175579          0.048622                0.015907   41.723373              0.050091          0.042427          0.037809      0.040414      0.038148
# 935    935            0.016038    41.311615          0.048712                0.016027   41.204082              0.049727          0.041065          0.038272      0.041005      0.037756
# 936    936            0.016168    41.543644          0.048869                0.015927   40.498260              0.049225          0.040259          0.037798      0.040269      0.039009
# 937    937            0.016086    40.890602          0.048423                0.015885   40.633492              0.049318          0.040201          0.038198      0.039804      0.038289
# 938    938            0.016054    41.446907          0.048803                0.015893   40.372398              0.049129          0.039890          0.038031      0.040825      0.038248
# 939    939            0.016099    41.226543          0.048654                0.015881   41.744492              0.050100          0.042321          0.038001      0.040260      0.038421
# 940    940            0.016054    41.263119          0.048677                0.015906   40.973297              0.049559          0.041148          0.037764      0.040761      0.037946
# 941    941            0.016142    41.213360          0.048641                0.015895   40.284668              0.049064          0.039806          0.037985      0.039933      0.038774
# 942    942            0.016057    41.070141          0.048546                0.015890   40.471935              0.049198          0.039983          0.038137      0.040436      0.037956
# 943    943            0.016078    41.127514          0.048584                0.015897   40.324142              0.049089          0.039900          0.037990      0.040109      0.038453
# 944    944            0.016071    41.128384          0.048585                0.015926   40.677959              0.049342          0.040156          0.038353      0.040726      0.037739
# 945    945            0.016099    41.829052          0.049058                0.015902   40.604305              0.049292          0.040507          0.037751      0.040873      0.038897
# 946    946            0.016099    40.806503          0.048361                0.015875   40.668049              0.049336          0.040325          0.038147      0.039814      0.038126
# 947    947            0.016074    41.210079          0.048636                0.015890   40.274666              0.049051          0.039820          0.037977      0.040308      0.038405
# 948    948            0.016079    40.996216          0.048492                0.015887   41.092873              0.049632          0.040509          0.038815      0.040201      0.038089
# 949    949            0.016052    41.616558          0.048914                0.015893   40.318993              0.049086          0.040031          0.037737      0.041083      0.038286
# 950    950            0.016128    40.911030          0.048430                0.015877   40.350563              0.049107          0.039895          0.038005      0.039703      0.038457
# 951    951            0.016052    41.129967          0.048580                0.015881   40.293461              0.049063          0.039759          0.038060      0.040418      0.038131
# 952    952            0.016077    40.921799          0.048438                0.015880   40.525822              0.049230          0.040045          0.038195      0.039855      0.038344
# 953    953            0.016087    42.012115          0.049158                0.015887   40.176506              0.048977          0.039777          0.037752      0.041736      0.038228
# 954    954            0.016104    40.703373          0.048285                0.015873   40.326279              0.049085          0.039738          0.038170      0.039648      0.038130
# 955    955            0.016053    40.908100          0.048427                0.015869   40.287266              0.049058          0.039835          0.037955      0.039823      0.038369
# 956    956            0.016050    41.146637          0.048589                0.015875   40.300285              0.049065          0.039760          0.038079      0.040412      0.038184
# 957    957            0.016080    41.067505          0.048536                0.015857   42.222351              0.050419          0.043123          0.038096      0.040062      0.038398
# 958    958            0.016037    41.149933          0.048593                0.015864   40.567768              0.049257          0.040462          0.037792      0.040701      0.037860
# 959    959            0.016095    41.119072          0.048568                0.015874   40.136395              0.048945          0.039665          0.037877      0.039927      0.038667
# 960    960            0.016048    40.958252          0.048459                0.015876   40.471882              0.049184          0.039867          0.038312      0.040320      0.037922
# 961    961            0.016060    40.948997          0.048454                0.015856   41.676781              0.050037          0.042310          0.037941      0.039802      0.038480
# 962    962            0.016051    41.309246          0.048698                0.015872   40.300232              0.049062          0.039812          0.038028      0.040973      0.037864
# 963    963            0.016073    41.040459          0.048514                0.015866   40.180119              0.048976          0.039765          0.037825      0.039887      0.038569
# 964    964            0.016049    41.032089          0.048506                0.015874   40.258537              0.049028          0.039652          0.038144      0.040333      0.038073
# 965    965            0.016074    41.358280          0.048727                0.015852   41.976509              0.050242          0.042769          0.038005      0.040521      0.038444
# 966    966            0.016042    40.740128          0.048306                0.015849   40.782768              0.049404          0.040744          0.037934      0.039904      0.037966
# 967    967            0.016088    41.180485          0.048606                0.015874   40.653877              0.049300          0.040610          0.037976      0.040195      0.038531
# 968    968            0.016035    40.880543          0.048402                0.015856   40.929607              0.049504          0.040579          0.038437      0.040234      0.037870
# 969    969            0.016028    41.364395          0.048728                0.015896   41.161949              0.049671          0.041628          0.037643      0.040678      0.038298
# 970    970            0.016100    40.728611          0.048293                0.015855   40.229992              0.049005          0.039664          0.038078      0.039564      0.038316
# 971    971            0.016014    41.049248          0.048515                0.015854   40.179985              0.048969          0.039707          0.037912      0.040387      0.038062
# 972    972            0.016046    40.769409          0.048322                0.015856   40.198246              0.048981          0.039674          0.038002      0.039630      0.038354
# 973    973            0.016019    41.176334          0.048599                0.015867   40.123444              0.048926          0.039653          0.037863      0.040879      0.037747
# 974    974            0.016064    41.267353          0.048662                0.015856   40.802223              0.049413          0.040981          0.037691      0.040196      0.038653
# 975    975            0.016059    40.672981          0.048254                0.015839   40.913048              0.049490          0.040975          0.037954      0.039739      0.038035
# 976    976            0.015992    41.359055          0.048715                0.015977   40.478207              0.049181          0.040266          0.037783      0.041008      0.037930
# 977    977            0.016151    40.891933          0.048396                0.015857   40.050358              0.048871          0.039534          0.037875      0.039499      0.038690
# 978    978            0.015994    40.673412          0.048253                0.015849   40.070995              0.048885          0.039526          0.037937      0.039923      0.037870
# 979    979            0.016025    40.971569          0.048458                0.015848   40.298080              0.049047          0.039796          0.038066      0.040177      0.038162
# 980    980            0.016038    41.242863          0.048639                0.015851   41.928436              0.050198          0.042929          0.037736      0.040482      0.038306
# 981    981            0.016051    40.594704          0.048197                0.015839   40.387760              0.049111          0.039978          0.038047      0.039634      0.038020
# 982    982            0.016019    41.115379          0.048552                0.015849   40.009563              0.048838          0.039521          0.037806      0.040354      0.038263
# 983    983            0.016040    40.720444          0.048282                0.015831   41.049316              0.049579          0.041097          0.038114      0.039678      0.038223
# 984    984            0.015998    41.084351          0.048533                0.015845   40.123177              0.048921          0.039831          0.037654      0.040713      0.037787
# 985    985            0.016072    40.874241          0.048386                0.015846   39.975056              0.048812          0.039503          0.037763      0.039625      0.038585
# 986    986            0.016017    40.844746          0.048366                0.015848   40.204453              0.048974          0.039581          0.038147      0.040231      0.037876
# 987    987            0.016031    40.793476          0.048332                0.015828   41.537018              0.049920          0.042158          0.037887      0.039674      0.038386
# 988    988            0.016013    41.033298          0.048496                0.015839   40.160393              0.048944          0.039772          0.037823      0.040636      0.037784
# 989    989            0.016049    40.906055          0.048406                0.015842   39.945118              0.048788          0.039478          0.037732      0.039767      0.038511
# 990    990            0.016017    40.792679          0.048328                0.015845   40.191734              0.048961          0.039519          0.038204      0.040107      0.037926
# 991    991            0.016027    41.073643          0.048521                0.015825   42.436733              0.050543          0.043720          0.037893      0.040166      0.038375
# 992    992            0.016016    40.710720          0.048272                0.015825   40.646954              0.049289          0.040681          0.037775      0.039985      0.037887
# 993    993            0.016062    41.029182          0.048486                0.015847   40.162739              0.048935          0.039869          0.037821      0.040015      0.038501
# 994    994            0.015996    40.567936          0.048172                0.015832   40.574505              0.049233          0.040133          0.038272      0.039866      0.037752
# 995    995            0.015998    41.466930          0.048778                0.015871   40.073357              0.048876          0.039796          0.037564      0.040951      0.038230
# 996    996            0.016078    40.507187          0.048126                0.015831   40.037514              0.048849          0.039456          0.037973      0.039342      0.038191
# 997    997            0.015995    40.684235          0.048250                0.015831   39.950138              0.048785          0.039403          0.037857      0.039780      0.038100
# 998    998            0.016001    40.767731          0.048307                0.015832   40.120037              0.048905          0.039515          0.038070      0.039996      0.038023
# 999    999            0.016017    41.075577          0.048516                0.015822   42.473408              0.050562          0.043846          0.037830      0.040228      0.038323

# %%
batch_size = 5000
test_batch_size = 5000
test_file_size = 20
data_directory_path = "/depot/cms/users/kuang14/Smart_Pixel/dataset_s_series/largerWindowPreliminary/dataset_3sr_16x16_50x12P5_parquets/contained/test"
tfrecords_dir_validation = "/depot/cms/users/kuang14/Smart_Pixel/tf_records/16x16test_3"
test_generator = DG.OptimizedDataGenerator(
    # Base directory where your parquet files are located
    dataset_base_dir = data_directory_path,
    is_directory_recursive = False,
    batch_size = test_batch_size,
    file_count = test_file_size,
    to_standardize = True,
    include_y_local = False,
    # Labels you want to extract
    labels_list = ['x-midplane', 'y-midplane', 'cotBeta'], 
    # Input shape for the model (time slices, height, width)
    input_shape = (TimeSlice, 16, 16),
    transpose = (0, 2, 3, 1),
    shuffle = False,
    files_from_end = False,
    
    # New parameters specific to this generator
    tfrecords_dir = tfrecords_dir_validation,
    use_time_stamps = -1,  # [0, 19]Specific time stamps to use
    quantize = False,  # Whether to use quantization during loading
    max_workers = 2  # For parallel processing
)
# Out:
# Processing Files...: 100%|██████████| 20/20 [00:27<00:00,  1.35s/it]
# Directory /depot/cms/users/kuang14/Smart_Pixel/tf_records/16x16test_3 is removed...
# Saving batches as TFRecords: 100%|██████████| 22/22 [01:19<00:00,  3.60s/it]
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# Metadata saved successfully ast /depot/cms/users/kuang14/Smart_Pixel/tf_records/16x16test_3/metadata.json
# Loading metadata from /depot/cms/users/kuang14/Smart_Pixel/tf_records/16x16test_3/metadata.json

# %%
model.summary()
# Out:
# Model: "smrtpxl_slim_tunable"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_pxls/ (InputLayer)    [(None, 16, 16, 20)]         0         []
#
#  avg_pooling_2d_proj_x (Ave  (None, 16, 1, 20)            0         ['input_pxls/[0][0]']
#  ragePooling2D)
#
#  avg_pooling_2d_proj_y (Ave  (None, 1, 16, 20)            0         ['input_pxls/[0][0]']
#  ragePooling2D)
#
#  reshape_proj_x (Reshape)    (None, 16, 20)               0         ['avg_pooling_2d_proj_x[0][0]'
#                                                                     ]
#
#  reshape_proj_y (Reshape)    (None, 16, 20)               0         ['avg_pooling_2d_proj_y[0][0]'
#                                                                     ]
#
#  conv1d_proj_x (Conv1D)      (None, 14, 5)                305       ['reshape_proj_x[0][0]']
#
#  conv1d_proj_y (Conv1D)      (None, 14, 5)                305       ['reshape_proj_y[0][0]']
#
#  concatenate (Concatenate)   (None, 28, 5)                0         ['conv1d_proj_x[0][0]',
#                                                                      'conv1d_proj_y[0][0]']
#
#  activation_tanh_1 (Activat  (None, 28, 5)                0         ['concatenate[0][0]']
#  ion)
#
#  flatten (Flatten)           (None, 140)                  0         ['activation_tanh_1[0][0]']
#
#  dense_1 (Dense)             (None, 16)                   2256      ['flatten[0][0]']
#
#  activation_tanh_2 (Activat  (None, 16)                   0         ['dense_1[0][0]']
#  ion)
#
#  dense_2 (Dense)             (None, 16)                   272       ['activation_tanh_2[0][0]']
#
#  activation_tanh_3 (Activat  (None, 16)                   0         ['dense_2[0][0]']
#  ion)
#
#  dense_3 (Dense)             (None, 3)                    51        ['activation_tanh_3[0][0]']
#
# ==================================================================================================
# Total params: 3189 (12.46 KB)
# Trainable params: 3189 (12.46 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# predicts test data
p_test = model.predict(test_generator)
# Out:
# 2025-09-24 22:08:29.351659: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2025-09-24 22:08:29.589745: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 22/22 [==============================] - 6s 159ms/step

# %%
complete_truth = None
for _, y in tqdm(test_generator):
        if complete_truth is None:
            complete_truth = y
        else:
            complete_truth = np.concatenate((complete_truth, y), axis=0)
# Out:
# 100%|██████████| 22/22 [00:03<00:00,  6.52it/s]

# %%
df = pd.DataFrame(p_test, columns=['x', 'y', 'cotB'])

# Store true values (only 3 for slim model)
df['xtrue'] = complete_truth[:,0]
df['ytrue'] = complete_truth[:,1] 
df['cotBtrue'] = complete_truth[:,2]  # Note: cotB is now at index 2

# Calculate residuals
df['x_residual'] = df['xtrue'] - df['x']
df['y_residual'] = df['ytrue'] - df['y']
df['cotB_residual'] = df['cotBtrue'] - df['cotB']

# ADD THESE LINES for the metric calculation cells:
residuals = df['x_residual']    # For X metrics
residualsy = df['y_residual']   # For Y metrics  
residualsB = df['cotB_residual'] # For CotB metrics

# Save results
df.to_csv("test_slim_model.csv", header=True, index=False)

# %% [markdown]
# ### Define Scaling factors first

# %%
Scaling_factors = test_generator.labels_scale
print(Scaling_factors)
# Out:
# [99.11786584 24.80232129  1.91059443]

# %%
SCALE_FACTOR_X = Scaling_factors[0]      # Scaling factor for x position [μm]
SCALE_FACTOR_Y = Scaling_factors[1]  # Scaling factor for y position [μm]
#SCALE_FACTOR_COTA = 8.95462059   # Scaling factor for cotangent alpha
SCALE_FACTOR_COTB = Scaling_factors[2] # Scaling factor for cotangent beta
#array([99.1550028 , 24.77847354,  8.95462059,  4.12538643])
print(SCALE_FACTOR_X, SCALE_FACTOR_Y, SCALE_FACTOR_COTB)
# Out:
# 99.11786583963806 24.802321286614486 1.9105944285582266

# %% [markdown]
# # residuals (mean, stdv)

# %%
def shortest_interval_68(data, center_type='mean'):
    """
    Compute the shortest interval that contains 68% of the data.
    """
    data = np.sort(data)
    n = len(data)
    ci_size = int(np.floor(0.68 * n))
    min_width = float("inf")
    min_i = 0

    for i in range(n - ci_size):
        width = data[i + ci_size] - data[i]
        if width < min_width:
            min_width = width
            min_i = i

    low = data[min_i]
    high = data[min_i + ci_size]

    if center_type == 'mean':
        center = np.mean(data)
    else:
        center = np.median(data)

    return {
        "center": center,
        "error_low": center - low,
        "error_high": high - center,
        "center_type": center_type
    }

def cotbeta_to_beta_degrees_correct(cotbeta_values):
    """Convert cotBeta to Beta in degrees, ensuring [0, 180] range"""
    beta_rad = np.arctan(1.0 / cotbeta_values)
    beta_deg = np.degrees(beta_rad)
    
    # Ensure angles are in [0, 180] range
    beta_deg = np.where(beta_deg < 0, beta_deg + 180, beta_deg)
    
    return beta_deg

# %%
# Convert cotB to beta in degrees
df['beta_true_deg'] = cotbeta_to_beta_degrees_correct(df['cotBtrue'])
df['beta_pred_deg'] = cotbeta_to_beta_degrees_correct(df['cotB'])
df['beta_deg_residual'] = df['beta_true_deg'] - df['beta_pred_deg']

# %%
# X residuals
x_result = shortest_interval_68(df['x_residual'], center_type='mean')
print(f"X: mean={x_result['center']*SCALE_FACTOR_X:.4f}, -error={x_result['error_low']*SCALE_FACTOR_X:.4f}, +error={x_result['error_high']*SCALE_FACTOR_X:.4f}")

# Y residuals  
y_result = shortest_interval_68(df['y_residual'], center_type='mean')
print(f"Y: mean={y_result['center']*SCALE_FACTOR_Y:.4f}, -error={y_result['error_low']*SCALE_FACTOR_Y:.4f}, +error={y_result['error_high']*SCALE_FACTOR_Y:.4f}")

# Beta residuals (in degrees, no scale factor needed)
beta_result = shortest_interval_68(df['beta_deg_residual'], center_type='mean')
print(f"Beta: mean={beta_result['center']:.4f}°, -error={beta_result['error_low']:.4f}°, +error={beta_result['error_high']:.4f}°")
# Out:
# X: mean=-0.2152, -error=4.4124, +error=4.7655
# Y: mean=0.0850, -error=0.9836, +error=1.0345
# Beta: mean=0.0034°, -error=0.8585°, +error=0.8265°

# %%
(np.mean(residuals)*SCALE_FACTOR_X, np.std(residuals)*SCALE_FACTOR_X)
# Out:
# (-0.21515204721305506, 5.331768160209284)

# %%
(np.mean(residualsy)*SCALE_FACTOR_Y, np.std(residualsy)*SCALE_FACTOR_Y)
# Out:
# (0.08499273358336072, 1.4583042553971832)

# %%
(np.mean(residualsB)*SCALE_FACTOR_COTB, np.std(residualsB)*SCALE_FACTOR_COTB)
# Out:
# (-0.00033625989557522514, 0.0489280561851807)

# %%
def residual_plot_slim(ax, thisdf, var1, var2, name, scaling=1.0):
    """
    Residual plot for slim model (no uncertainty estimates)
    Creates binned residual plot with statistical uncertainty bands
    """
    
    nbins = 15
    
    var1_scaled = thisdf[var1] * scaling
    var2_scaled = thisdf[var2] * scaling
    residual_scaled = var1_scaled - var2_scaled
    
    xmin = np.min(var1_scaled)
    xmax = np.max(var1_scaled)
    
    step = 1.0*(xmax-xmin)/nbins
    
    # Create binned scatter plot
    x = sns.regplot(x=var1_scaled, y=residual_scaled, x_bins=np.linspace(xmin,xmax,nbins), 
                   fit_reg=None, marker='.', ax=ax, scatter_kws={'s': 20})
    ax.set_xlabel('True ' + name)
    ax.set_ylabel('True - predicted ' + name)
    
    # Calculate binned statistics for uncertainty bands
    bin_centers = []
    means = []
    stds = []
    
    for i in range(nbins):
        bin_mask = (var1_scaled >= xmin + i*step) & (var1_scaled < xmin + (i+1)*step)
        if np.sum(bin_mask) > 0:  # Only if there are points in this bin
            bin_centers.append(xmin + (i+0.5)*step)
            bin_residuals = residual_scaled[bin_mask]
            means.append(np.mean(bin_residuals))
            stds.append(np.std(bin_residuals))
    
    bin_centers = np.array(bin_centers)
    means = np.array(means)
    stds = np.array(stds)
    
    # Create uncertainty bands (±1 standard deviation)
    upbar = means + stds
    downbar = means - stds
    
    # Fill between for uncertainty band
    ax.fill_between(bin_centers, upbar, downbar, alpha=0.3, color='lightblue')
    
    return ax

def residual_plot_deg_slim(ax, thisdf, var1, var2, name, scaling=1.0):
    """
    Residual plot for cotangent values converted to degrees
    """
    # If not a cotangent variable, use regular residual plot
    if 'cot' not in var1:
        return residual_plot_slim(ax, thisdf, var1, var2, name, scaling=scaling)

    # Convert cotangent to degrees
    def inverse_cot(cota):
        a = np.arctan(1.0/cota)
        a = np.where(a < 0, a + np.pi, a)  # Using np.where for array operations
        return a    

    # Create temporary copies for degree conversion
    thisdf_copy = thisdf.copy()
    
    # Convert predictions to degrees
    thisdf_copy['angle'] = inverse_cot(thisdf_copy[var2].values * scaling) * 180 / np.pi
    
    # Convert true values to degrees  
    thisdf_copy['angletrue'] = inverse_cot(thisdf_copy[var1].values * scaling) * 180 / np.pi
    
    # Calculate angular residuals
    angular_residuals = thisdf_copy['angletrue'] - thisdf_copy['angle']
    
    var1_deg = thisdf_copy['angletrue']
    
    nbins = 15
    xmin = np.min(var1_deg)
    xmax = np.max(var1_deg)
    step = (xmax - xmin) / nbins
    
    # Create binned scatter plot
    sns.regplot(x=var1_deg, y=angular_residuals, x_bins=np.linspace(xmin, xmax, nbins), 
               fit_reg=None, marker='.', ax=ax, scatter_kws={'s': 20})
    ax.set_xlabel('True ' + name)
    ax.set_ylabel('True - predicted ' + name)
    
    # Calculate binned statistics
    bin_centers = []
    means = []
    stds = []
    
    for i in range(nbins):
        bin_mask = (var1_deg >= xmin + i*step) & (var1_deg < xmin + (i+1)*step)
        if np.sum(bin_mask) > 0:
            bin_centers.append(xmin + (i+0.5)*step)
            bin_residuals = angular_residuals[bin_mask]
            means.append(np.mean(bin_residuals))
            stds.append(np.std(bin_residuals))
    
    bin_centers = np.array(bin_centers)
    means = np.array(means)
    stds = np.array(stds)
    
    # Create uncertainty bands
    upbar = means + stds
    downbar = means - stds
    
    ax.fill_between(bin_centers, upbar, downbar, alpha=0.3, color='lightblue')
    
    return ax

# %%
def create_slim_summary_plot_horizontal(df, base_dir):
   """
   Create horizontal summary residual plot for Slim model (1x3 layout)
   """
   fig, axes = plt.subplots(1, 3, figsize=(18, 6))
   fig.tight_layout(pad=4.0)
   
   # X residuals
   residual_plot_slim(axes[0], df, 'xtrue', 'x', r'$x$ [μm]', scaling=SCALE_FACTOR_X)
   axes[0].axhline(0, color='gray', linestyle=':', alpha=0.7)
   axes[0].axvline(-25, color='gray', linestyle=':', alpha=0.7)
   axes[0].axvline(25, color='gray', linestyle=':', alpha=0.7)
   axes[0].set_ylim([-10, 10])
   
   # Y residuals
   residual_plot_slim(axes[1], df, 'ytrue', 'y', r'$y$ [μm]', scaling=SCALE_FACTOR_Y)
   axes[1].axhline(0, color='gray', linestyle=':', alpha=0.7)
   axes[1].axvline(-6.25, color='gray', linestyle=':', alpha=0.7)
   axes[1].axvline(6.25, color='gray', linestyle=':', alpha=0.7)
   axes[1].set_ylim([-10, 10])
   
   # CotB residuals (converted to degrees)
   residual_plot_deg_slim(axes[2], df, 'cotBtrue', 'cotB', r'$β$ [deg]', scaling=SCALE_FACTOR_COTB)
   axes[2].axhline(0, color='gray', linestyle=':', alpha=0.7)
   axes[2].axvline(90, color='gray', linestyle=':', alpha=0.7)
   axes[2].set_ylim([-10, 10])
   
   # Save figure
   save_fig_path = os.path.join(base_dir, 'slim_residual_summary_horizontal.png')
   plt.savefig(save_fig_path, dpi=300, bbox_inches='tight')
   plt.show()
   
   return fig

# %%
create_slim_summary_plot_horizontal(df, base_dir)

# %%
def create_slim_summary_plot_horizontal(df, base_dir):
   """
   Create horizontal summary residual plot for Slim model (1x3 layout)
   """
   fig, axes = plt.subplots(1, 3, figsize=(18, 6))
   fig.tight_layout(pad=4.0)
   
   # X residuals
   residual_plot_slim(axes[0], df, 'xtrue', 'x', r'$x$ [μm]', scaling=SCALE_FACTOR_X)
   axes[0].axhline(0, color='gray', linestyle=':', alpha=0.7)
   axes[0].axvline(-25, color='gray', linestyle=':', alpha=0.7)
   axes[0].axvline(25, color='gray', linestyle=':', alpha=0.7)
   axes[0].set_ylim([-10, 10])
   
   # Y residuals
   residual_plot_slim(axes[1], df, 'ytrue', 'y', r'$y$ [μm]', scaling=SCALE_FACTOR_Y)
   axes[1].axhline(0, color='gray', linestyle=':', alpha=0.7)
   axes[1].axvline(-6.25, color='gray', linestyle=':', alpha=0.7)
   axes[1].axvline(6.25, color='gray', linestyle=':', alpha=0.7)
   axes[1].set_ylim([-10, 10])
   
   # CotB residuals (converted to degrees)
   residual_plot_deg_slim(axes[2], df, 'cotBtrue', 'cotB', r'$β$ [deg]', scaling=SCALE_FACTOR_COTB)
   axes[2].axhline(0, color='gray', linestyle=':', alpha=0.7)
   axes[2].axvline(90, color='gray', linestyle=':', alpha=0.7)
   axes[2].set_ylim([-10, 10])
   
   # Save figure
   save_fig_path = os.path.join(base_dir, 'slim_residual_summary_horizontal.png')
   plt.savefig(save_fig_path, dpi=300, bbox_inches='tight')
   plt.show()
   
   return fig

# %%
print(os.getcwd())
# Out:
# /depot/cms/private/users/kuang14/Smart_Pixel/Full_n_slim

# %%
df.to_parquet('/depot/cms/private/users/kuang14/Smart_Pixel/Full_n_slim/Model_performance/Slim_Models/Slim_Model_20t_full_precision_8869b160.parquet')
